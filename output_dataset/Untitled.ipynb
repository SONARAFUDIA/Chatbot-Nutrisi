    "Mengenal 5 Penyebab dan Faktor Risiko Obesitas pada Anak",
    "Mengenal Vegan, Seperti Apa Pola Makan dan Manfaatnya?",
    "Mengenali Aturan Makan Cokelat untuk Penderita Diabetes",
    "Menu Diet DEBM Saat Puasa dan Tips Aman Menerapkannya",
    "Minuman yang Aman untuk Penderita Diabetes, Lezat dan Menyegarkan",
    "Obesitas",
    "Obesitas Morbid, Kenali Gejala hingga Cara Mengobatinya",
    "Obesitas pada Anak: Ciri-Ciri, Penyebab, dan Komplikasi",
    "Olahraga untuk Orang Obesitas yang Aman, Apa Saja?",
    "Operasi Bariatrik",
    "Panduan Gizi Olahraga bagi Atlet dan Anda yang Aktif Secara Fisik",
    "Penting! Hindari 10 Menu Sarapan yang Bikin Gemuk",
    "Penyebab Lapar Setelah Olahraga dan Tips Mengatasinya",
    "Peran Ibu dalam Tumbuh Kembang Anak",
    "Pilihan Camilan Sehat untuk Anak 1 Tahun",
    "Pilihan Makanan untuk Anak Diare, Penting Diketahui Orangtua",
    "Pola Makan Vegetarian yang Sehat",
    "Pola Makan untuk Atasi Obesitas yang Mudah Dicoba",
    "Probiotik dan Prebiotik: Perbedaan, Manfaat, Efek Samping, dll",
    "Rahasia Cara Mengasah 6 Keterampilan Penting Si Kecil",
    "Sarapan Sebelum Olahraga Pagi, Perlu atau Tidak?",
    "Seberapa Efektif Timun Turunkan Gula Darah Penderita Diabetes?",
    "Serba-serbi Diet Flexitarian, Cocok untuk Vegetarian Pemula",
    "Stunted-Obesity, Anak Stunting Berisiko Alami Obesitas",
    "Supaya Tak Bosan, Coba 9 Resep Olahan Tahu yang Lezat Ini",
    "Tubuh Terlalu Kurus? Ini 9 Rekomendasi Susu Penambah Berat Badan untuk Dewasa dan Anak!",
    "Usus Sapi, Ketahui Nutrisi, Manfaat, dan Risiko Mengonsumsinya",
    "Vegetarian, Kenali Jenis hingga Manfaat dari Pola Makan Ini",
    "Waspadai 15 Jenis Ikan dengan Kandungan Merkuri Tinggi",
    "Waspadai Risiko Obesitas pada Bayi yang Gemuk"
]

# ==========================================
# 2. PROSES FILTERING
# ==========================================
def filter_dataset(input_file, output_file):
    try:
        # Membaca dataset
        print(f"Membaca file: {input_file}...")
        df = pd.read_csv(input_file)
        
        # Validasi kolom 'title'
        if 'title' not in df.columns:
            print("ERROR: Kolom 'title' tidak ditemukan dalam dataset.")
            print(f"Kolom yang tersedia: {list(df.columns)}")
            return

        # Melakukan filtering
        # Menggunakan .isin() untuk memilih baris dimana 'title' ada di list target
        filtered_df = df[df['title'].isin(target_titles)]
        
        # Simpan hasil
        filtered_df.to_csv(output_file, index=False)
        
        print("\n=== HASIL PROSES ===")
        print(f"Total baris awal      : {len(df)}")
        print(f"Total baris tersimpan : {len(filtered_df)}")
        print(f"File disimpan ke      : {output_file}")
        
    except FileNotFoundError:
        print(f"Error: File '{input_file}' tidak ditemukan.")
    except Exception as e:
        print(f"Terjadi kesalahan: {e}")

# ==========================================
# 3. EKSEKUSI
# ==========================================
# Ganti 'nama_file_dataset_anda.csv' dengan nama file CSV asli Anda yang memiliki kolom:
# [doc_id, chunk_id, title, text, url, intent, token_count]
input_filename = 'processed_chunks.csv' 
output_filename = 'dataset_filtered_health_goals.csv'

if __name__ == "__main__":
    filter_dataset(input_filename, output_filename)
# Out:
# Membaca file: processed_chunks.csv...
#
# === HASIL PROSES ===
# Total baris awal      : 7661
# Total baris tersimpan : 757
# File disimpan ke      : dataset_filtered_health_goals.csv
