# %% [markdown]
# # Import

# %%
import pandas as pd
import numpy as np
import re
import string

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import LatentDirichletAllocation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %% [markdown]
# # Preprocessing function

# %%
class TextPreprocessor:
    def __init__(self):
        # Inisialisasi Stemmer dan Stopword Remover
        self.stemmer = StemmerFactory().create_stemmer()
        self.stopword_remover = StopWordRemoverFactory().create_stop_word_remover()
        
        # Stopwords tambahan khusus domain nutrisi
        self.custom_stopwords = set([
            'sub', 'topik', 'embed', 'health', 'tool', 'bmi',
            'hellosehat', 'com', 'https', 'www'
        ])
        
    def case_folding(self, text):
        """Convert text to lowercase"""
        return text.lower()
    
    def remove_noise(self, text):
        # Remove URLs
        text = re.sub(r'https?://\S+|www\.\S+', '', text)
        # Remove special characters and numbers
        text = re.sub(r'[^a-zA-Z\s]', ' ', text)
        # Remove extra whitespace
        text = re.sub(r'\s+', ' ', text).strip()
        return text
    
    def tokenize(self, text):
        return word_tokenize(text)
    
    def remove_stopwords(self, text):
        text = self.stopword_remover.remove(text)
        tokens = text.split()
        tokens = [t for t in tokens if t not in self.custom_stopwords]
        return ' '.join(tokens)
    
    def stem_text(self, text):
        return self.stemmer.stem(text)
    
    def preprocess(self, text):
        text = self.case_folding(text)
        text = self.remove_noise(text)
        text = self.remove_stopwords(text)
        text = self.stem_text(text)
        return text

preprocessor = TextPreprocessor()

# %% [markdown]
# # Preprocessing Data

# %%
df1 = pd.read_csv('hellosehat_dataset_10.csv', sep=';', quotechar='"', encoding='utf-8')

print(f"Jumlah artikel: {len(df1)}")
print(f"Kolom: {df1.columns.tolist()}")
print(f"\nContoh data:")
print(df1.head(2))
# Out:
# Jumlah artikel: 614
# Kolom: ['URL', 'Judul', 'Konten']
#
# Contoh data:
#                                                  URL  \
# 0  https://hellosehat.com/nutrisi/berat-badan-tur...
# 1  https://hellosehat.com/nutrisi/tips-makan-seha...
#
#                                                Judul  \
# 0  Kenali 9 Penyebab Perut Buncit dan Cara Mengat...
# 1    8 Merk Oven Gas Terbaik, Cocok untuk Bisnis Kue
#
#                                               Konten
# 0  Perut buncit memang mampu memengaruhi penampil...
# 1  Bagi Anda yang gemar bikin kue, oven gas menja...

# %%
df2 = pd.read_csv('alodokter_dataset_10.csv', sep=';', quotechar='"', encoding='utf-8')

print(f"Jumlah artikel: {len(df2)}")
print(f"Kolom: {df2.columns.tolist()}")
print(f"\nContoh data:")
print(df2.head(2))
# Out:
# Jumlah artikel: 931
# Kolom: ['URL', 'Judul', 'Konten']
#
# Contoh data:
#                                                  URL  \
# 0  https://www.alodokter.com/6-makanan-dengan-ind...
# 1  https://www.alodokter.com/cayenne-pepper-kenal...
#
#                                                Judul  \
# 0  6 Makanan dengan Indeks Glikemik Tinggi yang P...
# 1  Cayenne Pepper, Kenali Manfaat di Balik Rasa P...
#
#                                               Konten
# 0  Penderita diabetes sebaiknya membatasi konsums...
# 1  Cayenne pepper adalah salah satu jenis cabai t...

# %%
df_combine = pd.concat([df1, df2], ignore_index=True)
print(f"Total dokumen setelah concat: {len(df_combine)}")
print(f"Index range: {df_combine.index.min()} - {df_combine.index.max()}")
print(f"Kolom: {df_combine.columns.tolist()}")
# Out:
# Total dokumen setelah concat: 1545
# Index range: 0 - 1544
# Kolom: ['URL', 'Judul', 'Konten']

# %% [markdown]
# # Saving Files (skip if this step file exist)

# %%
# Preprocessing untuk judul dan konten
df_combine['judul_clean'] = df_combine['Judul'].apply(preprocessor.preprocess)
df_combine['konten_clean'] = df_combine['Konten'].apply(preprocessor.preprocess)

# Gabungkan judul dan konten untuk representasi dokumen
df_combine['document'] = df_combine['judul_clean'] + ' ' + df_combine['konten_clean']
# Simpan semua hasil preprocessing
df_combine[['judul_clean', 'konten_clean', 'document']].to_csv('preprocessing_results.csv', index=False, encoding='utf-8')

print("Preprocessing selesai")
print(f"\nContoh hasil preprocessing:")
print(f"Original: {df_combine['Judul'].iloc[0][:100]}...")
print(f"Cleaned: {df_combine['judul_clean'].iloc[0][:100]}...")
# Out:
# Preprocessing selesai
#
# Contoh hasil preprocessing:
# Original: Kenali 9 Penyebab Perut Buncit dan Cara Mengatasinya...
# Cleaned: kenal sebab perut buncit cara atas...

# %% [markdown]
# # Test Query

# %%
df_prepro = pd.read_csv('preprocessing_results.csv', encoding='utf-8')

print(f"Kolom: {df_prepro.columns.tolist()}")

print("File preprocessing")
print(f"Index range: {df_prepro.index.min()} - {df_prepro.index.max()}")
print(f"Jumlah artikel: {len(df_prepro)}")
# Out:
# Kolom: ['judul_clean', 'konten_clean', 'document']
# File preprocessing
# Index range: 0 - 1544
# Jumlah artikel: 1545

# %%
HEALTH_GOALS = {
    'menurunkan_berat_badan': {
        'keywords': ['kurus', 'langsing', 'diet', 'turun berat', 'menurunkan berat badan', 
                    'obesitas', 'gemuk', 'lemak'],
        'related_concepts': ['kalori', 'olahraga', 'metabolisme', 'lemak', 'berat badan']
    },
    'kesehatan_anak': {
        'keywords': ['anak', 'balita', 'tumbuh kembang', 'pertumbuhan anak', 'nutrisi anak',
                    'obesitas anak', 'gizi anak'],
        'related_concepts': ['anak', 'pertumbuhan', 'obesitas', 'gizi', 'vitamin']
    },
    'detoksifikasi': {
        'keywords': ['detoks', 'detoksifikasi', 'racun', 'membersihkan tubuh', 'juice cleanse'],
        'related_concepts': ['jus', 'detoks', 'racun', 'enzim', 'vitamin']
    },
    'diet_khusus': {
        'keywords': ['gluten free', 'bebas gluten', 'celiac', 'alergi', 'sensitivitas'],
        'related_concepts': ['gluten', 'celiac', 'tepung', 'alergi', 'protein']
    },
    'memasak_sehat': {
        'keywords': ['resep', 'memasak', 'cara masak', 'teknik memasak', 'blanching',
                    'olahan', 'makanan sehat'],
        'related_concepts': ['masak', 'teknik', 'nutrisi', 'sayur', 'vitamin']
    }
}

# %%
class QueryProcessor:
    def __init__(self, health_goals):
        self.health_goals = health_goals
        self.preprocessor = TextPreprocessor()
        
    def extract_intent(self, query):
        """Ekstrak tujuan kesehatan dari query"""
        query_clean = self.preprocessor.preprocess(query)
        query_lower = query.lower()
        
        # Hitung skor untuk setiap tujuan kesehatan
        scores = {}
        for goal, info in self.health_goals.items():
            score = 0
            # Cek keyword match
            for keyword in info['keywords']:
                if keyword in query_lower:
                    score += 2  # Bobot lebih tinggi untuk keyword match
            # Cek related concept match
            for concept in info['related_concepts']:
                if concept in query_clean:
                    score += 1
            scores[goal] = score
        
        # Ambil tujuan dengan skor tertinggi
        if max(scores.values()) > 0:
            best_goal = max(scores, key=scores.get)
            return best_goal, scores[best_goal]
        return None, 0
    
    def expand_query(self, query, intent):
        """Expand query dengan konsep terkait"""
        if intent and intent in self.health_goals:
            related_concepts = self.health_goals[intent]['related_concepts']
            expanded = query + ' ' + ' '.join(related_concepts)
            return self.preprocessor.preprocess(expanded)
        return self.preprocessor.preprocess(query)

query_processor = QueryProcessor(HEALTH_GOALS)

# %%
# Test intent extraction
test_queries = [
    "Bagaimana cara menurunkan berat badan dengan sehat?",
    "Resep makanan untuk anak obesitas",
    "Apakah cold pressed juice bagus untuk detoks?",
    "Makanan bebas gluten untuk penderita celiac",
    "Cara memasak sayuran agar nutrisinya tidak hilang"
]

print("\nContoh Intent Extraction:")
for query in test_queries:
    intent, score = query_processor.extract_intent(query)
    expanded = query_processor.expand_query(query, intent)
    print(f"\nQuery: {query}")
    print(f"Intent: {intent} (score: {score})")
    print(f"Expanded: {expanded[:80]}...")
# Out:
# Contoh Intent Extraction:
#
# Query: Bagaimana cara menurunkan berat badan dengan sehat?
# Intent: menurunkan_berat_badan (score: 3)
# Expanded: bagaimana cara turun berat badan sehat kalori olahraga metabolisme lemak berat b...
#
# Query: Resep makanan untuk anak obesitas
# Intent: kesehatan_anak (score: 4)
# Expanded: resep makan anak obesitas anak tumbuh obesitas gizi vitamin...
#
# Query: Apakah cold pressed juice bagus untuk detoks?
# Intent: detoksifikasi (score: 3)
# Expanded: cold pressed juice bagus detoks jus detoks racun enzim vitamin...
#
# Query: Makanan bebas gluten untuk penderita celiac
# Intent: diet_khusus (score: 6)
# Expanded: makan bebas gluten derita celiac gluten celiac tepung alergi protein...
#
# Query: Cara memasak sayuran agar nutrisinya tidak hilang
# Intent: memasak_sehat (score: 5)
# Expanded: cara masak sayur nutrisi hilang masak teknik nutrisi sayur vitamin...

# %%
# TF-IDF vectorizer
tfidf_vectorizer = TfidfVectorizer(
    max_features=500,  # Batasi jumlah fitur
    min_df=1,  # Minimal muncul di 1 dokumen
    max_df=0.8,  # Maksimal muncul di 80% dokumen
    ngram_range=(1, 2),  # Unigram dan bigram
    sublinear_tf=True  # Gunakan log scaling untuk TF
)

# %%
# Fit dan transform dokumen
tfidf_matrix = tfidf_vectorizer.fit_transform(df_prepro['document'])

print(f"TF-IDF matrix shape: {tfidf_matrix.shape}")
print(f"  - Jumlah dokumen: {tfidf_matrix.shape[0]}")
print(f"  - Jumlah fitur (terms): {tfidf_matrix.shape[1]}")

# Top terms berdasarkan TF-IDF
feature_names = tfidf_vectorizer.get_feature_names_out()
tfidf_scores = tfidf_matrix.sum(axis=0).A1
top_terms_idx = tfidf_scores.argsort()[-20:][::-1]
top_terms = [(feature_names[i], tfidf_scores[i]) for i in top_terms_idx]

print(f"\nTop 20 terms berdasarkan TF-IDF score:")
for i, (term, score) in enumerate(top_terms, 1):
    print(f"{i:2d}. {term:20s} : {score:.2f}")
# Out:
# TF-IDF matrix shape: (1545, 500)
#   - Jumlah dokumen: 1545
#   - Jumlah fitur (terms): 500
#
# Top 20 terms berdasarkan TF-IDF score:
#  1. manfaat              : 91.91
#  2. buah                 : 79.87
#  3. vitamin              : 76.41
#  4. darah                : 72.59
#  5. lemak                : 71.17
#  6. tinggi               : 71.08
#  7. hari                 : 70.92
#  8. sakit                : 70.61
#  9. jaga                 : 70.57
# 10. nutrisi              : 70.13
# 11. bantu                : 70.09
# 12. turun                : 69.70
# 13. buat                 : 69.12
# 14. berat                : 68.60
# 15. kurang               : 68.41
# 16. badan                : 67.73
# 17. gula                 : 67.22
# 18. dalam                : 66.95
# 19. berat badan          : 66.53
# 20. anda                 : 65.69

# %%
class RetrievalEngine:
    def __init__(self, tfidf_vectorizer, tfidf_matrix, df_combine, query_processor):
        self.vectorizer = tfidf_vectorizer
        self.tfidf_matrix = tfidf_matrix
        self.df_combine = df_combine
        self.query_processor = query_processor
        
    def search(self, query, top_k=5, use_intent=True):
        """Search dokumen berdasarkan query"""
        intent, intent_score = self.query_processor.extract_intent(query)
        
        if use_intent and intent:
            query_processed = self.query_processor.expand_query(query, intent)
        else:
            query_processed = self.query_processor.preprocessor.preprocess(query)
        
        query_vector = self.vectorizer.transform([query_processed])
        similarities = cosine_similarity(query_vector, self.tfidf_matrix).flatten()
        top_indices = similarities.argsort()[-top_k:][::-1]
        
        results = []
        for rank, idx in enumerate(top_indices, 1):  # ← PERBAIKAN: enumerate dengan start=1
            results.append({
                'rank': rank,
                'doc_id': int(idx),  # ← KUNCI: gunakan idx langsung (bukan df.index[idx])
                'title': self.df_combine.iloc[idx]['Judul'],
                'url': self.df_combine.iloc[idx]['URL'],
                'similarity_score': float(similarities[idx]),
                'snippet': self.df_combine.iloc[idx]['Konten'][:200] + '...'
            })
        
        return {
            'query': query,
            'intent': intent,
            'intent_score': intent_score,
            'query_processed': query_processed,
            'results': results,
            # 'snippet': snippet,
        }

# Inisialisasi ulang retrieval engine
retrieval_engine = RetrievalEngine(tfidf_vectorizer, tfidf_matrix, df_combine, query_processor)

# %%
test_query = "cara menurunkan berat badan"
result = retrieval_engine.search(test_query, top_k=5)

print(f"\nQuery: {test_query}")
print(f"Intent: {result['intent']} (score: {result['intent_score']})")
print(f"Query processed: {result['query_processed'][:100]}...")
print(f"\nTop 5 Results:")
for r in result['results']:
    print(f"{r['rank']}. [ID:{r['doc_id']}] {r['title'][:60]}...")
    print(f"   Score: {r['similarity_score']:.4f}")
    print(f"   Snippet: {r['snippet']}")
# Out:
# Query: cara menurunkan berat badan
# Intent: menurunkan_berat_badan (score: 3)
# Query processed: cara turun berat badan kalori olahraga metabolisme lemak berat badan...
#
# Top 5 Results:
# 1. [ID:281] Berapa Kg Berat Badan yang Boleh Turun dalam Seminggu?...
#    Score: 0.4971
#    Snippet: Belakangan ini, banyak metode diet bermunculan dengan klaim dapat menurunkan berat badan dalam seminggu. Selain mengurangi asupan makan dan memperbanyak olahraga, diet tersebut menganjurkan penggunaan...
# 2. [ID:312] Bagaimana Penurunan Berat Badan yang Baik?...
#    Score: 0.4322
#    Snippet: Banyak yang mengira menurunkan berat badan merupakan pertanda lemak tubuh hilang atau berkurang. Faktanya tidak demikian. Bbanyak hal yang memengaruhi penurunan berat badan. Simak penjelasan kaitan be...
# 3. [ID:1202] Cara Menurunkan Berat Badan Dalam 1 Minggu Secara Alami...
#    Score: 0.4224
#    Snippet: Meski terkesan memaksa, menurunkan berat badan dalam 1 minggu secara alami sangat mungkin terjadi. Hal ini bahkan sudah dibuktikan oleh banyak orang. Penasaran seperti apa langkah-langkahnya? Mari pel...
# 4. [ID:142] Lebih Baik Diet atau Olahraga untuk Turun Berat Badan?...
#    Score: 0.4213
#    Snippet: Menurunkan berat badan sering kali menjadi tujuan banyak orang untuk hidup lebih sehat dan percaya diri. Namun, muncul banyak pertanyaan mana yang lebih efektif untuk menurunkan berat badan, diet atau...
# 5. [ID:446] Kenapa Orang Gemuk Susah Kurusnya?...
#    Score: 0.4033
#    Snippet: Meski sudah diet dan berolahraga, banyak orang gemuk yang tak juga bisa turun berat badan secara signifikan. Terutama bila tubuhnya sudah bisa digolongkan sebagai obesitas . Namun, apa yang jadi penye...

# %% [markdown]
# # Evaluation for Queries

# %% [markdown]
# EVALUATION_QUERIES = [
#     {
#         'query': 'cara menurunkan berat badan dengan jus',
#         'relevant_docs': [0, 2, 3, 4, 5],
#         'intent': 'menurunkan_berat_badan'
#     },
#     {
#         'query': 'obesitas pada anak dan cara mengatasinya',
#         'relevant_docs': [0, 5, 10, 11, 12],
#         'intent': 'kesehatan_anak'
#     },
#     {
#         'query': 'teknik memasak yang mempertahankan nutrisi',
#         'relevant_docs': [2, 5, 6, 7, 8],
#         'intent': 'memasak_sehat'
#     },
#     {
#         'query': 'resep makanan tanpa gluten',
#         'relevant_docs': [0, 5, 14, 16, 22],
#         'intent': 'diet_khusus'
#     },
#     {
#         'query': 'diet detoks dengan cold pressed juice',
#         'relevant_docs': [0, 3, 4, 7, 12],
#         'intent': 'detoksifikasi'
#     },
#     {
#         'query': 'makanan sehat untuk anak gemuk',
#         'relevant_docs': [0, 1, 2, 3, 4],
#         'intent': 'kesehatan_anak'
#     },
#
# ]

# %%
# Fungsi bantuan untuk membuat Ground Truth secara otomatis
# Mencari dokumen yang mengandung kata-kata dari query
def generate_ground_truth(queries, df, preprocessor):
    updated_queries = []
    
    print("Generating Ground Truth (mencari ID dokumen yang relevan)...")
    
    for item in queries:
        query_text = item['query']
        # Preprocess query untuk mendapatkan kata dasar
        clean_query = preprocessor.preprocess(query_text)
        query_terms = clean_query.split()
        
        relevant_ids = []
        
        # Scan semua dokumen
        for idx, row in df.iterrows():
            # Gabung judul dan konten clean untuk pengecekan
            doc_content = (str(row['judul_clean']) + " " + str(row['konten_clean']))
            
            # Cek apakah SEMUA atau SEBAGIAN BESAR kata kunci muncul di dokumen
            # Kita pakai logika: Minimal 75% kata kunci harus ada
            matches = sum(1 for term in query_terms if term in doc_content)
            threshold = len(query_terms) * 0.75 
            
            if matches >= threshold:
                relevant_ids.append(idx)
        
        # Update item dengan relevant_docs yang baru ditemukan
        item['relevant_docs'] = relevant_ids
        updated_queries.append(item)
        print(f"Query: '{query_text}' -> Found {len(relevant_ids)} relevant docs.")
        
    return updated_queries

# Definisi Query Awal
RAW_QUERIES = [
    {
        'query': 'cara menurunkan berat badan dengan jus',
        'intent': 'menurunkan_berat_badan'
    },
    {
        'query': 'obesitas pada anak dan cara mengatasinya',
        'intent': 'kesehatan_anak'
    },
    {
        'query': 'teknik memasak yang mempertahankan nutrisi',
        'intent': 'memasak_sehat'
    },
    {
        'query': 'resep makanan tanpa gluten',
        'intent': 'diet_khusus'
    },
    {
        'query': 'diet detoks dengan cold pressed juice',
        'intent': 'detoksifikasi'
    },
    {
        'query': 'makanan sehat untuk anak gemuk',
        'intent': 'kesehatan_anak'
    }
]

# Generate Ground Truth yang Valid menggunakan df_prepro (hasil preprocessing)
# Pastikan df_prepro sudah ter-load (dari Cell 14)
EVALUATION_QUERIES = generate_ground_truth(RAW_QUERIES, df_prepro, preprocessor)
# Out:
# Generating Ground Truth (mencari ID dokumen yang relevan)...
# Query: 'cara menurunkan berat badan dengan jus' -> Found 650 relevant docs.
# Query: 'obesitas pada anak dan cara mengatasinya' -> Found 319 relevant docs.
# Query: 'teknik memasak yang mempertahankan nutrisi' -> Found 170 relevant docs.
# Query: 'resep makanan tanpa gluten' -> Found 10 relevant docs.
# Query: 'diet detoks dengan cold pressed juice' -> Found 3 relevant docs.
# Query: 'makanan sehat untuk anak gemuk' -> Found 379 relevant docs.

# %%
print("Verifikasi EVALUATION_QUERIES:")
for i, eq in enumerate(EVALUATION_QUERIES, 1):
    print(f"\n{i}. Query: {eq['query']}")
    print(f"   Relevant docs: {eq['relevant_docs']}")
    
    for doc_id in eq['relevant_docs']:
        if doc_id < len(df_combine):
            print(f"   ✓ Doc {doc_id}: {df_combine.iloc[doc_id]['Judul'][:60]}...")
        else:
            print(f"   ✗ Doc {doc_id}: INDEX OUT OF RANGE! (max: {len(df)-1})")
# Out:
# Verifikasi EVALUATION_QUERIES:
#
# 1. Query: cara menurunkan berat badan dengan jus
#    Relevant docs: [0, 4, 5, 7, 9, 11, 12, 13, 14, 15, 16, 23, 24, 25, 26, 28, 29, 30, 31, 34, 36, 39, 42, 44, 45, 46, 50, 53, 56, 59, 60, 63, 64, 65, 67, 68, 69, 73, 74, 77, 79, 80, 81, 82, 83, 84, 86, 87, 88, 91, 92, 93, 96, 97, 98, 99, 100, 104, 105, 106, 108, 109, 111, 112, 113, 118, 119, 120, 122, 123, 124, 125, 127, 128, 129, 131, 132, 133, 136, 138, 139, 140, 141, 144, 145, 149, 150, 152, 153, 155, 157, 158, 160, 162, 164, 166, 167, 171, 174, 175, 177, 178, 180, 187, 188, 189, 191, 192, 194, 195, 197, 199, 201, 203, 204, 206, 209, 213, 218, 219, 224, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 241, 242, 244, 245, 246, 248, 250, 251, 254, 257, 260, 261, 266, 268, 269, 271, 272, 273, 276, 277, 279, 281, 283, 286, 287, 288, 295, 296, 297, 303, 304, 306, 309, 310, 312, 315, 317, 318, 319, 320, 321, 322, 323, 325, 326, 327, 330, 339, 341, 342, 344, 345, 346, 348, 349, 350, 351, 355, 356, 357, 359, 360, 361, 362, 365, 367, 370, 371, 372, 373, 375, 377, 382, 383, 384, 385, 387, 390, 391, 396, 404, 405, 407, 408, 413, 414, 416, 417, 419, 421, 423, 424, 425, 426, 427, 428, 429, 430, 435, 437, 438, 439, 443, 444, 445, 446, 447, 450, 452, 453, 455, 456, 458, 459, 462, 463, 467, 470, 471, 472, 473, 475, 477, 478, 479, 480, 482, 485, 486, 488, 490, 494, 498, 499, 500, 503, 504, 505, 508, 510, 511, 519, 521, 522, 524, 527, 528, 533, 534, 537, 538, 540, 542, 543, 546, 548, 549, 550, 552, 554, 556, 559, 561, 562, 563, 567, 568, 569, 574, 575, 576, 577, 578, 579, 580, 581, 587, 590, 591, 592, 593, 594, 595, 596, 598, 602, 603, 605, 606, 612, 613, 614, 615, 616, 621, 628, 629, 630, 633, 635, 636, 637, 641, 647, 651, 653, 659, 661, 664, 665, 678, 686, 688, 689, 698, 700, 703, 706, 715, 720, 723, 727, 730, 732, 740, 746, 747, 750, 752, 753, 754, 755, 759, 760, 761, 763, 764, 768, 770, 772, 776, 777, 778, 781, 785, 786, 787, 789, 792, 797, 798, 799, 802, 803, 804, 805, 808, 809, 811, 813, 814, 816, 818, 819, 822, 823, 825, 826, 827, 829, 842, 844, 846, 847, 848, 849, 850, 853, 855, 857, 858, 864, 867, 872, 875, 876, 881, 884, 886, 888, 891, 896, 897, 904, 905, 909, 923, 926, 927, 930, 931, 935, 937, 941, 943, 944, 949, 950, 952, 958, 960, 961, 962, 967, 968, 983, 984, 986, 987, 988, 989, 990, 991, 993, 994, 997, 999, 1004, 1006, 1009, 1014, 1015, 1016, 1017, 1023, 1026, 1027, 1028, 1030, 1033, 1034, 1037, 1039, 1040, 1045, 1047, 1050, 1051, 1052, 1053, 1058, 1059, 1061, 1068, 1070, 1075, 1087, 1088, 1089, 1090, 1095, 1097, 1099, 1100, 1101, 1102, 1109, 1128, 1134, 1136, 1137, 1140, 1141, 1147, 1154, 1157, 1158, 1159, 1160, 1161, 1162, 1164, 1168, 1169, 1172, 1173, 1175, 1176, 1179, 1183, 1184, 1186, 1188, 1189, 1193, 1198, 1202, 1209, 1218, 1219, 1224, 1230, 1231, 1233, 1237, 1244, 1246, 1249, 1250, 1254, 1264, 1269, 1271, 1274, 1276, 1278, 1282, 1284, 1287, 1289, 1290, 1291, 1295, 1296, 1297, 1298, 1301, 1303, 1306, 1311, 1312, 1313, 1320, 1321, 1323, 1324, 1325, 1327, 1331, 1337, 1339, 1341, 1344, 1345, 1349, 1352, 1356, 1357, 1358, 1359, 1361, 1362, 1363, 1364, 1365, 1368, 1370, 1372, 1379, 1380, 1381, 1382, 1385, 1389, 1391, 1393, 1396, 1401, 1402, 1408, 1413, 1415, 1419, 1420, 1421, 1430, 1431, 1432, 1435, 1436, 1437, 1438, 1439, 1447, 1450, 1451, 1453, 1454, 1461, 1462, 1466, 1468, 1469, 1473, 1482, 1487, 1489, 1490, 1491, 1495, 1496, 1499, 1502, 1503, 1504, 1506, 1511, 1512, 1514, 1517, 1522, 1524, 1526, 1529, 1534, 1535, 1537, 1539, 1540]
#    ✓ Doc 0: Kenali 9 Penyebab Perut Buncit dan Cara Mengatasinya...
#    ✓ Doc 4: Apakah Sering Buang Air Bisa Menurunkan Berat Badan?...
#    ✓ Doc 5: Penyebab Terlalu Kurus dan Dampaknya pada Kesehatan...
#    ✓ Doc 7: 9 Manfaat Air Mineral yang Tak Boleh Disepelekan...
#    ✓ Doc 9: Porsi Makan Diet yang Tepat untuk Menurunkan Berat Badan...
#    ✓ Doc 11: Manfaat Madu Penggemuk Badan, Apakah Ada?...
#    ✓ Doc 12: Diet Nasi...
#    ✓ Doc 13: 7 Cara Sehat Menaikkan Berat Badan dan Tetap Bertahan Lama...
#    ✓ Doc 14: Mengenal Skinny Fat, Kondisi Tubuh Kurus juga Gemuk...
#    ✓ Doc 15: Mengulik Penyebab dan Cara Mengatasi Gemuk Air...
#    ✓ Doc 16: 10 Sumber Karbohidrat Terbaik, Mana yang Paling Sehat?...
#    ✓ Doc 23: 10 Bahaya Diet Ketat bagi Kesehatan Tubuh...
#    ✓ Doc 24: Mengenal Diet Karbo dan Panduan Menjalaninya...
#    ✓ Doc 25: Intip 5 Cara Orangtua Mengelola Obesitas pada Anak...
#    ✓ Doc 26: Berbagai Cara Menghilangkan Lemak di Leher (Double Chin) yan...
#    ✓ Doc 28: 5 Kreasi Resep Bubur yang Nikmat untuk Sarapan dan Selingan ...
#    ✓ Doc 29: 10 Manfaat Durian, Si Buah dengan Aroma yang Khas...
#    ✓ Doc 30: 5 Inspirasi Resep Mille Crepes yang Lezat dan Lembut...
#    ✓ Doc 31: Gastric Balloon Insertion, Ampuhkah Mengatasi Kelebihan Bera...
#    ✓ Doc 34: 8 Pilihan Minuman Sehat Pengganti Kopi di Pagi Hari...
#    ✓ Doc 36: Panduan Mudah Menjalani Diet Lacto-ovo Vegetarian...
#    ✓ Doc 39: Panduan Diet Defisit Kalori untuk Turunkan Berat Badan...
#    ✓ Doc 42: 11 Camilan Sehat dan Enak untuk yang Sedang Diet...
#    ✓ Doc 44: 8 Masalah Kesehatan yang Mengintai Akibat Makan Tidak Teratu...
#    ✓ Doc 45: Pola Makan untuk Atasi Obesitas yang Mudah Dicoba...
#    ✓ Doc 46: 10 Strategi Jitu Menurunkan Berat Badan Saat Puasa...
#    ✓ Doc 50: Diet Endomorph, Turunkan Berat Badan Sesuai Tipe Tubuh...
#    ✓ Doc 53: Diet Tanpa Sayur, Ketahui Risikonya bagi Tubuh...
#    ✓ Doc 56: Berapa Minimal Kalori yang Harus Dipenuhi untuk Diet?...
#    ✓ Doc 59: Ingin Berat Badan Naik secara Alami? Coba 4 Vitamin dan Mine...
#    ✓ Doc 60: 10 Tanda Berat Badan Naik yang Harus Anda Sadari...
#    ✓ Doc 63: Mengenal Vegan, Seperti Apa Pola Makan dan Manfaatnya?...
#    ✓ Doc 64: 7 Menu Sayuran untuk Diet yang Mudah Dibuat...
#    ✓ Doc 65: Apa Itu Lemak Perut? Ini Cara Tepat Menghilangkannya...
#    ✓ Doc 67: Apakah Boleh Minum Kopi Sebelum Olahraga? Cek Faktanya...
#    ✓ Doc 68: 9 Penyebab Lemak di Perut Bawah yang Sering Disepelekan...
#    ✓ Doc 69: Cara Diet OCD yang Aman untuk Turunkan Berat Badan...
#    ✓ Doc 73: Agar Tetap Sehat, Ini Inspirasi Menu Diet Tanpa Nasi...
#    ✓ Doc 74: 8 Manfaat Jamur Portobello dan Cara Mengolahnya...
#    ✓ Doc 77: 3 Manfaat Yoghurt untuk Diet dan Cara Konsumsinya...
#    ✓ Doc 79: Diet Ketat Apakah Boleh? Ini Cara Aman Mencobanya...
#    ✓ Doc 80: 5 Resep Infused Water yang Segar dan Mudah Dibuat...
#    ✓ Doc 81: Urutan Makan yang Benar Sesuai Asupan Gizi dan Table Manner...
#    ✓ Doc 82: 8 Menu Sarapan Sehat agar Berenergi Sepanjang Hari...
#    ✓ Doc 83: Benarkah Seseorang Bisa Gemuk Tapi Tetap Sehat?...
#    ✓ Doc 84: 7 Takjil Sehat dan Nikmat untuk Buka Puasa...
#    ✓ Doc 86: 10 Motivasi Diet untuk Konsisten Turunkan Berat Badan...
#    ✓ Doc 87: Mencegah Obesitas Sarcopenia di Usia Paruh Baya...
#    ✓ Doc 88: Cara Mengukur Lingkar Pinggang dan Tips Mengecilkannya...
#    ✓ Doc 91: 6 Cara Mengatasi Kekurangan Natrium dalam Tubuh...
#    ✓ Doc 92: Diet Golongan Darah, Seperti Apa Aturannya?...
#    ✓ Doc 93: 10 Rekomendasi Madu yang Bagus untuk Daya Tahan Tubuh...
#    ✓ Doc 96: 7 Cara Mengatasi Lemak yang Berlipat di Ketiak...
#    ✓ Doc 97: 11 Manfaat Taoge, Tingkatkan Kesuburan hingga Cegah Kanker...
#    ✓ Doc 98: 5 Cara Membuat Nasi Jagung dan Resep Lezat Lainnya...
#    ✓ Doc 99: 6 Pilihan Makanan Penetral setelah Makan Daging...
#    ✓ Doc 100: Obesitas pada Anak: Ciri-Ciri, Penyebab, dan Komplikasi...
#    ✓ Doc 104: Cara Sehat Makan Buah dan 8 Manfaat yang Diperoleh...
#    ✓ Doc 105: Wajib Tahu, 11 Makanan Ini Ternyata Gampang Bikin Gemuk...
#    ✓ Doc 106: 10 Menu Diet untuk Mengecilkan Paha dan Bokong...
#    ✓ Doc 108: Buah untuk Menurunkan Berat Badan yang Kaya Serat dan Air...
#    ✓ Doc 109: 8 Minuman Pengganjal Perut yang Mengenyangkan...
#    ✓ Doc 111: Diet Golongan Darah B: Aturan, Menu, dan Pro-Kontra...
#    ✓ Doc 112: Diet Detoksifikasi, Benarkah Efektif Buang Racun Tubuh?...
#    ✓ Doc 113: 8 Rekomendasi Merk Selai Kacang untuk Diet yang Wajib Dicoba...
#    ✓ Doc 118: Bolehkah Menurunkan Berat Badan dengan Minum Obat Pencahar?...
#    ✓ Doc 119: 10 Sumber Karbohidrat untuk Diet, Mana yang Paling Baik?...
#    ✓ Doc 120: Resep Pizza Teflon Rumahan yang Sehat, Lezat, dan Tidak Ribe...
#    ✓ Doc 122: Bagaimana Cara Menghitung Kalori Makanan?...
#    ✓ Doc 123: 11 Penyebab Berat Badan Susah Turun meski Sudah Diet...
#    ✓ Doc 124: Panduan Lengkap untuk Mencoba Diet Oatmeal...
#    ✓ Doc 125: Mengenal Fase Plateau, Penyebab BB Tidak Mau Turun Lagi...
#    ✓ Doc 127: Obesitas Sentral, Ketika Perut Buncit Picu Penyakit Kronis...
#    ✓ Doc 128: Diet Golongan Darah A, Inilah Aturan dan Pro-Kontranya...
#    ✓ Doc 129: Serba-serbi Alat Pembakar Lemak, Benarkah Bisa Bikin Langsin...
#    ✓ Doc 131: Menu Sahur yang Cocok Dikonsumsi Saat Diet Selama Puasa...
#    ✓ Doc 132: Cokelat Bisa Bantu Turunkan Berat Badan, Ini Tips Konsumsiny...
#    ✓ Doc 133: Susu Kental Manis, Ini Kandungan dan Cara Sehat Konsumsinya...
#    ✓ Doc 136: Mengenal Klasifikasi Tingkat Obesitas dari Pengukuran IMT...
#    ✓ Doc 138: 11 Manfaat Pisang Ambon dan Kandungan Gizinya...
#    ✓ Doc 139: 13 Rekomendasi Merk Susu Rendah Lemak, Aman untuk Diet...
#    ✓ Doc 140: Cara Tepat untuk Menjaga Hidrasi Saat Main Bola...
#    ✓ Doc 141: 9 Pilihan Makanan Sahur yang Tepat agar Kuat Berpuasa...
#    ✓ Doc 144: Contoh Menu Diet 1200 Kalori dengan Bahan yang Praktis dan T...
#    ✓ Doc 145: 9 Bahaya dari Obesitas yang Perlu Anda Waspadai...
#    ✓ Doc 149: 7 Inspirasi Resep Jus Mangga yang Super Segar dan Nikmat...
#    ✓ Doc 150: 12 Manfaat Buah Gandaria yang Kaya Antioksidan Alami...
#    ✓ Doc 152: Mual setelah Minum Kopi? Ini Penyebab dan Tips Mengatasinya...
#    ✓ Doc 153: Bisakah Puasa Menurunkan Berat Badan?...
#    ✓ Doc 155: Chia Seed untuk Diet dan Cara Tepat Konsumsinya...
#    ✓ Doc 157: 10 Cara Menurunkan Nafsu Makan untuk Jaga Berat Badan...
#    ✓ Doc 158: Panduan Makan Setelah Menjalani Operasi Bariatrik...
#    ✓ Doc 160: Rekomendasi Menu Diet Sehat 30 Hari, Mudah dan Praktis...
#    ✓ Doc 162: Mengenal Proses Detoksifikasi Tubuh, Cara Kerja, dan Manfaat...
#    ✓ Doc 164: 9 Penyebab Lemak di Perut Bawah yang Sering Disepelekan...
#    ✓ Doc 166: Benarkah Hobi Ngemil Bisa Bikin Badan Gemuk?...
#    ✓ Doc 167: Berbagai Tes Kesehatan untuk Diagnosis Obesitas...
#    ✓ Doc 171: 10 Penyebab Berat Badan Naik yang Perlu Diwaspadai...
#    ✓ Doc 174: 8 Manfaat Cuka Putih untuk Kesehatan yang Jarang Diketahui...
#    ✓ Doc 175: 7 Variasi Resep Nasi Goreng yang Lezat dan Mudah Dibuat...
#    ✓ Doc 177: 3 Resep Olahan Labu Kuning yang Lezat dan Sehat...
#    ✓ Doc 178: 7 Kebiasaan Diet yang Salah dan Tanda Diet Tidak Tepat...
#    ✓ Doc 180: Mengenal Panduan Diet Karnivora, Apakah Aman bagi Tubuh?...
#    ✓ Doc 187: Mengenal Bahaya Arsenik yang Ada dalam Makanan...
#    ✓ Doc 188: Manfaat dan Cara Sehat Konsumsi Beras Merah untuk Diet...
#    ✓ Doc 189: 4 Resep Olahan Kacang Hijau Selain Burjo, yang Segar dan Men...
#    ✓ Doc 191: Mengenal Peskatarian, Vegetarian yang Juga Makan Ikan dan Se...
#    ✓ Doc 192: 9 Menu Sarapan Sehat untuk Bantu Sukseskan Diet Anda...
#    ✓ Doc 194: Penyebab Lapar Setelah Olahraga dan Tips Mengatasinya...
#    ✓ Doc 195: 10 Pilihan Menu Buka Puasa Sehat dan Mengenyangkan...
#    ✓ Doc 197: Kurma Cocok untuk Diet, Ini Alasan dan Aturan Makannya...
#    ✓ Doc 199: 12 Kebiasaan yang Bikin Cepat Kurus...
#    ✓ Doc 201: 4 Kesalahan Makan Oatmeal yang Bikin Berat Badan Malah Naik...
#    ✓ Doc 203: Semua yang Perlu Anda Tahu Seputar Diet Sehat...
#    ✓ Doc 204: 17 Makanan Tinggi Serat yang Baik untuk Kesehatan...
#    ✓ Doc 206: Sedot Lemak (Liposuction)...
#    ✓ Doc 209: 7 Manfaat Klorofil untuk Kesehatan, Plus Efek Sampingnya...
#    ✓ Doc 213: Inspirasi Resep Aneka Jus dari Buah dan Sayur, yang Praktis ...
#    ✓ Doc 218: 13 Obat Diet Alami yang Membantu Menurunkan Berat Badan...
#    ✓ Doc 219: 7 Bahaya Kebiasaan Minum Minuman Manis bagi Kesehatan...
#    ✓ Doc 224: 7 Cara Cepat Menggemukkan Badan untuk Anda yang Terlalu Kuru...
#    ✓ Doc 226: Penting! Hindari 10 Menu Sarapan yang Bikin Gemuk...
#    ✓ Doc 227: Mengenal Mindful Eating, Makan Perlahan dan Penuh Kesadaran...
#    ✓ Doc 228: 8 Cara Diet Cepat Kurus dan Rekomendasi Menunya...
#    ✓ Doc 229: Ozempic untuk Diet, Apakah Efektif?...
#    ✓ Doc 230: 9 Tips Puasa Sehat agar Tetap Segar di Bulan Ramadan...
#    ✓ Doc 231: 7 Cara Aman Menambah Berat Badan saat Puasa...
#    ✓ Doc 232: Ketahui Fungsi Penting Elektrolit dalam Tubuh Manusia...
#    ✓ Doc 233: Efek Samping Diet Detoks bagi Tubuh Anda...
#    ✓ Doc 234: Inspirasi Menu Diet Rendah Kalori untuk Seminggu...
#    ✓ Doc 235: 11 Manfaat Sehat Jahe, Cegah Mual hingga Lawan Kanker...
#    ✓ Doc 241: Penyebab Kekurangan Natrium dan Faktor Risikonya...
#    ✓ Doc 242: Mengenal Diet CICO, Pastikan Kalori Masuk dan Keluar Sama...
#    ✓ Doc 244: Tips Diet Rendah Kalori untuk Turunkan Berat Badan...
#    ✓ Doc 245: 7 Jadwal Minum Air Putih yang Baik untuk Penuhi Cairan Tubuh...
#    ✓ Doc 246: Diet Seminggu untuk Turun 10 Kg Berbahaya, Ini Alternatifnya...
#    ✓ Doc 248: Mengenal Doping, Jenis, dan Efek Sampingnya...
#    ✓ Doc 250: Mengenal Mangga Kweni dan 5 Manfaatnya untuk Kesehatan...
#    ✓ Doc 251: Diet Keto, Panduan Pola Makan Rendah Karbohidrat...
#    ✓ Doc 254: Minum Kopi untuk Diet, Benarkah Efektif?...
#    ✓ Doc 257: Ragam Makanan yang Harus Dihindari Saat Anda Sedang Diet...
#    ✓ Doc 260: Jangan Dilewatkan, Ini 7 Manfaat Makan Malam bagi Tubuh...
#    ✓ Doc 261: 9 Manfaat Jus Buah Naga dan Pisang, Plus Cara Membuatnya...
#    ✓ Doc 266: 11 Jus untuk Diet, Kaya Serat dan Air yang Bisa Dicoba...
#    ✓ Doc 268: 5 Cara Memasak Kentang Selain Digoreng...
#    ✓ Doc 269: 8 Cara Mengatasi Obesitas, Gaya Hidup hingga Pengobatan...
#    ✓ Doc 271: 8 Menu Makan Malam untuk Diet yang Tidak Bikin Gemuk...
#    ✓ Doc 272: Air Rebusan dari Keran dan Air Galon, Mana yang Lebih Sehat?...
#    ✓ Doc 273: Berat Badan Turun Karena Diet Thonon, Apakah Ini Efektif dan...
#    ✓ Doc 276: 8 Minuman yang Bisa Membantu Turunkan Berat Badan...
#    ✓ Doc 277: 7 Merek Vitamin Penambah Nafsu Makan untuk Dewasa di Apotek...
#    ✓ Doc 279: Mengenal Diet Food Combining dan Aturan Makannya...
#    ✓ Doc 281: Berapa Kg Berat Badan yang Boleh Turun dalam Seminggu?...
#    ✓ Doc 283: Menu Diet DEBM Saat Puasa dan Tips Aman Menerapkannya...
#    ✓ Doc 286: Kenapa Makan Junk Food Bikin Badan Gemuk?...
#    ✓ Doc 287: Supaya Tak Bosan, Coba 9 Resep Olahan Tahu yang Lezat Ini...
#    ✓ Doc 288: Obesitas Morbid, Kenali Gejala hingga Cara Mengobatinya...
#    ✓ Doc 295: 12 Pilihan Buah Kaya Serat yang Baik untuk Kesehatan...
#    ✓ Doc 296: 7 Inspirasi Menu Makan Siang untuk Diet dan Resepnya...
#    ✓ Doc 297: Badan Gemuk Akibat Faktor Genetik, Bagaimana Mengatasinya?...
#    ✓ Doc 303: Pilihan Obat Obesitas, Mulai dari Resep Dokter hingga Herbal...
#    ✓ Doc 304: 8 Minyak Goreng untuk Diet yang Rendah Kalori...
#    ✓ Doc 306: 8 Manfaat Tanaman Porang, Umbi Pengganti Nasi Kaya Serat...
#    ✓ Doc 309: 6 Pengganti Gula untuk Diet Anda, Apa Saja?...
#    ✓ Doc 310: 5 Cara Mengecilkan Paha agar Lebih Ramping...
#    ✓ Doc 312: Bagaimana Penurunan Berat Badan yang Baik?...
#    ✓ Doc 315: 8 Makanan Pendukung untuk Mengecilkan Perut Buncit...
#    ✓ Doc 317: 13 Makanan Penurun Berat Badan agar Tubuh Ramping...
#    ✓ Doc 318: Tanda dan Gejala Obesitas yang Perlu Anda Waspadai...
#    ✓ Doc 319: 11 Manfaat Tahu, Cegah Sembelit hingga Risiko Kanker...
#    ✓ Doc 320: Bosan dengan Mie yang Itu-Itu Saja? Coba 3 Resep Mie Shirata...
#    ✓ Doc 321: 11 Pilihan Makanan Diet yang Cocok untuk Pemula...
#    ✓ Doc 322: Plastic Wrap untuk Diet, Benarkah Bisa Mengecilkan Perut?...
#    ✓ Doc 323: Liquid Diet, Berikut Pengertian dan Panduan Melakukannya...
#    ✓ Doc 325: 5 Manfaat Mengonsumsi Suplemen BCAA untuk Membentuk Otot...
#    ✓ Doc 326: Ingin Turun Berat Badan? Ini 10 Merek Teh Hijau yang Bagus u...
#    ✓ Doc 327: 7 Manfaat Buah Kering untuk Kesehatan dan Risikonya...
#    ✓ Doc 330: Lemak Punggung, Lemak yang Paling Sering Tak Disadari...
#    ✓ Doc 339: Kapankah Waktu Terbaik untuk Minum Chia Seed?...
#    ✓ Doc 341: Badan Kurus Belum Tentu Lebih Sehat dari Orang Gemuk...
#    ✓ Doc 342: Berat Badan Tak Juga Turun? Bantu dengan Diet Hormon Ini!...
#    ✓ Doc 344: Tahu atau Tempe, Mana Olahan Kedelai yang Lebih Bergizi?...
#    ✓ Doc 345: 12 Merk Beras Merah yang Bagus dan Cocok untuk Diet...
#    ✓ Doc 346: 4 Manfaat Food Diary, Bantu Jaga Pola Makan Harian...
#    ✓ Doc 348: Benarkah Berjemur Bisa Menurunkan Berat Badan?...
#    ✓ Doc 349: Ketahui Cara Menimbang Berat Badan yang Tepat...
#    ✓ Doc 350: 7 Ciri-Ciri Berat Badan Turun, Ketahui Idealnya Seperti Apa...
#    ✓ Doc 351: 10 Efek Samping Akibat Kebanyakan Makan Alpukat...
#    ✓ Doc 355: Meski Tampak Sama, Ini Perbedaan Overweight dan Obesitas...
#    ✓ Doc 356: 5 Rekomendasi Diet Sehat untuk Usia 40 Tahun ke Atas...
#    ✓ Doc 357: 9 Manfaat Jalan Kaki setelah Makan, 15 Menit Saja Cukup...
#    ✓ Doc 359: Inspirasi Menu Diet Rendah Karbo untuk Seminggu...
#    ✓ Doc 360: Berapa Banyak Tubuh Membakar Kalori Saat Tidur?...
#    ✓ Doc 361: Apakah Efektif Melakukan Diet Puasa Nabi Daud?...
#    ✓ Doc 362: Panduan Lengkap Menjalani Diet Paleo...
#    ✓ Doc 365: 7 Bahaya Makan Mi Instan Mentah bagi Kesehatan Tubuh...
#    ✓ Doc 367: Panduan Diet Tinggi Serat, Cara Sehat untuk Turunkan Berat B...
#    ✓ Doc 370: 12 Makanan Rendah Karbohidrat untuk Diet Anda...
#    ✓ Doc 371: Diet Jamur, Begini Panduan Lengkap dan Inspirasi Menunya...
#    ✓ Doc 372: 10 Bahaya Perut Buncit, Pemicu Penyakit Kronis...
#    ✓ Doc 373: Ingin Lemak Hilang Lebih Cepat? Lakukan Olahraga Sebelum Sar...
#    ✓ Doc 375: Mengenal Diet Puasa alias Intermittent Fasting: Manfaat dan ...
#    ✓ Doc 377: Serba-serbi Obat Pelangsing untuk Menurunkan Berat Badan...
#    ✓ Doc 382: Apa Saja Efek Makan Buah di Malam Hari bagi Tubuh?...
#    ✓ Doc 383: 9 Jenis Ikan yang Bagus untuk Diet, Ada Tuna hingga Cakalang...
#    ✓ Doc 384: 10 Jenis Makanan Penyebab Obesitas yang Harus Dibatasi...
#    ✓ Doc 385: Cara Melakukan Diet Rendah Lemak dan 4 Manfaatnya...
#    ✓ Doc 387: Begini Cara Diet tapi Tetap Bisa Makan Enak...
#    ✓ Doc 390: 9 Makanan Sehat yang Berpotensi Membuat Panjang Umur...
#    ✓ Doc 391: 6 Cara Memenuhi Kebutuhan Cairan Tubuh dengan Sehat...
#    ✓ Doc 396: 11 Manfaat Ubi Ungu selain Menurunkan Berat Badan...
#    ✓ Doc 404: Diet Air Putih, Begini Aturannya untuk Turunkan Berat Badan...
#    ✓ Doc 405: Obesitas...
#    ✓ Doc 407: 4 Resep Kale Lezat dan Nikmat yang Bukan Salad...
#    ✓ Doc 408: Lemak di Paha Sulit Dihilangkan? Ini Penyebabnya...
#    ✓ Doc 413: Panduan Menjalani Diet Mayo yang Sehat...
#    ✓ Doc 414: Mengecilkan Perut dengan Minum Air Jeruk Nipis, Benarkah Ter...
#    ✓ Doc 416: Resistensi Leptin, Salah Satu Penyebab Lemak Menumpuk Sampai...
#    ✓ Doc 417: 12 Resep Smoothies yang Mengenyangkan...
#    ✓ Doc 419: Ini 11 Penyakit yang Bisa Membuat Gemuk tanpa Disadari...
#    ✓ Doc 421: Resep Sayur Oyong yang Sehat dan Lezat...
#    ✓ Doc 423: 8 Pilihan Minuman Rendah Kalori untuk Program Diet Anda...
#    ✓ Doc 424: Diet Golongan Darah O, Apakah Terbukti Bermanfaat?...
#    ✓ Doc 425: 10 Cara Menahan Godaan Makan agar Diet Tidak Gagal...
#    ✓ Doc 426: 5 Manfaat Makan Pakai Tangan dan Risiko Kesehatannya...
#    ✓ Doc 427: Makanan yang Mengandung 2000 Kalori untuk Diet Harian...
#    ✓ Doc 428: Kenapa Orang dengan Badan Kurus Perutnya Bisa Buncit?...
#    ✓ Doc 429: 10 Rekomendasi Merk Kopi Hitam Terbaik untuk Diet...
#    ✓ Doc 430: CoolSculpting untuk Hancurkan Lemak yang Sulit Hilang...
#    ✓ Doc 435: 8 Kondisi yang Bikin Badan Kurus meski Banyak Makan...
#    ✓ Doc 437: 8 Menu Diet Saat Menjalani Puasa Beserta Panduannya...
#    ✓ Doc 438: Cara Diet Intermittent Fasting yang Aman untuk Pemula...
#    ✓ Doc 439: Jenis Makanan Penyebab Berat Badan Cepat Naik...
#    ✓ Doc 443: 15 Cara Menurunkan Berat Badan dengan Sehat dan Cepat...
#    ✓ Doc 444: Panduan 30 Hari Diet Bebas Gula untuk Hidup Lebih Sehat...
#    ✓ Doc 445: Fakta Diet Hanya Minum Jus untuk Menurunkan Berat Badan...
#    ✓ Doc 446: Kenapa Orang Gemuk Susah Kurusnya?...
#    ✓ Doc 447: Diet Anti-Aging, Benarkah Mampu Memperpanjang Usia?...
#    ✓ Doc 450: Lebih Baik Minum Jus atau Makan Buah Langsung?...
#    ✓ Doc 452: 12 Manfaat Makan Jantung Pisang untuk Kesehatan...
#    ✓ Doc 453: 9 Cara Buka Puasa yang Sehat agar Puasa Makin Lancar...
#    ✓ Doc 455: 11 Manfaat Daun Selada yang Belum Banyak Diketahui...
#    ✓ Doc 456: Fungsi Kasein untuk Membentuk Otot dan Tips Memilih Produkny...
#    ✓ Doc 458: 7 Cara Diet Sehat agar Tubuh Ideal dan Tetap Bugar...
#    ✓ Doc 459: 8 Efek Puasa Tanpa Sahur yang Perlu Diwaspadai...
#    ✓ Doc 462: Wajib Tahu, Ini 9 Penyebab Berat Badan Naik Saat Diet...
#    ✓ Doc 463: Cara Membuat Kopi Cappuccino Versi yang Lebih Sehat...
#    ✓ Doc 467: Operasi Bariatrik...
#    ✓ Doc 470: Serba-serbi Diet Flexitarian, Cocok untuk Vegetarian Pemula...
#    ✓ Doc 471: Manfaat Diet Ornish, Diet Vegetarian yang Sehatkan Jantung...
#    ✓ Doc 472: Makan Pelan-Pelan Lebih Sehat dari Makan Cepat, Mengapa?...
#    ✓ Doc 473: Olahraga untuk Orang Obesitas yang Aman, Apa Saja?...
#    ✓ Doc 475: Berapa Idealnya Kalori yang Harus Dibakar Setiap Hari?...
#    ✓ Doc 477: Mengulik Diet South Beach untuk Menurunkan Berat Badan...
#    ✓ Doc 478: 10 Kebiasaan yang Dapat Menambah Berat Badan dan Diet Gagal...
#    ✓ Doc 479: 8 Cara Efektif untuk Membakar Lemak Tubuh...
#    ✓ Doc 480: 5 Manfaat Kayu Manis untuk Diet Menurunkan Berat Badan...
#    ✓ Doc 482: 10 Merk Frozen Food yang Enak dan Harganya Terjangkau...
#    ✓ Doc 485: 12 Sereal untuk Diet yang Rendah Kalori untuk Turunkan BB...
#    ✓ Doc 486: Makanan dan Minuman yang Baik Dikonsumsi Setelah Bersepeda...
#    ✓ Doc 488: 8 Manfaat Grapefruit, Cegah Diabetes hingga Batu Ginjal...
#    ✓ Doc 490: Obesitas Mengurangi Kesuburan Wanita...
#    ✓ Doc 494: Mengenal Lemak Subkutan, Lemak yang Paling Umum Terbentuk...
#    ✓ Doc 498: Tubuh Terlalu Kurus? Ini 9 Rekomendasi Susu Penambah Berat B...
#    ✓ Doc 499: Ingin Makan Banyak tapi Tidak Mau Gemuk? Begini Caranya...
#    ✓ Doc 500: Diet Plant-Based, Apa Bedanya dengan Diet Vegan dan Vegetari...
#    ✓ Doc 503: 6 Efek Samping Kelebihan Vitamin D yang Perlu Diwaspadai...
#    ✓ Doc 504: Mengupas Manfaat Jahe untuk Menurunkan Berat Badan...
#    ✓ Doc 505: 10 Cara Membakar Kalori dari Aktivitas Sehari-hari...
#    ✓ Doc 508: Kavitasi Lemak...
#    ✓ Doc 510: 7 Trik Tetap Sukses Turun Berat Badan meski Sedang Liburan...
#    ✓ Doc 511: Manfaat Air Kelapa untuk Diet dan Tips Mengonsumsinya...
#    ✓ Doc 519: Berat Badan Naik? Mungkin Karena Anda Tidur Dengan Lampu Men...
#    ✓ Doc 521: Cara Mengecilkan Perut Buncit yang Mudah dan Aman...
#    ✓ Doc 522: Tidak Makan Malam dan Risikonya bagi Kesehatan...
#    ✓ Doc 524: Pola Makan Vegetarian, Inilah Jenis, Manfaat, dan Pertimbang...
#    ✓ Doc 527: Turunkan Berat Badan dengan Air Putih, Mitos atau Fakta?...
#    ✓ Doc 528: Benarkah Lemon Ampuh untuk Diet?...
#    ✓ Doc 533: Mengulik Cryolipolysis untuk Menghilangkan Lemak...
#    ✓ Doc 534: Polifagia, Kondisi Lapar Berlebihan meski Sudah Makan Banyak...
#    ✓ Doc 537: 14 Manfaat Minyak Zaitun, Sehatkan Jantung hingga Sendi...
#    ✓ Doc 538: Wajib Coba, Ini 4 Resep Orek Tempe yang Enak dan Praktis...
#    ✓ Doc 540: Mengenal Diet Yoyo dan Berbagai Efeknya pada Tubuh...
#    ✓ Doc 542: Menu Diet DEBM untuk Seminggu yang Bisa Anda Ikuti...
#    ✓ Doc 543: Panduan Gizi Olahraga bagi Atlet dan Anda yang Aktif Secara ...
#    ✓ Doc 546: 8 Resep Overnight Oat untuk Sarapan Sehat dan Praktis...
#    ✓ Doc 548: Cold-Pressed Juice, Apakah Efektif untuk Detoks dan Diet?...
#    ✓ Doc 549: Apa yang Menyebabkan Nafsu Makan Menurun?...
#    ✓ Doc 550: 8 Manfaat Sehat Daun Kale, Si Hijau yang Kaya Gizi...
#    ✓ Doc 552: 7 Penyebab Berat Badan Naik Saat Puasa yang Sering Diabaikan...
#    ✓ Doc 554: 10 Cara Diet Tanpa Olahraga bagi Orang yang Malas Gerak...
#    ✓ Doc 556: Apakah Boleh Makan Keju Saat Sedang Diet?...
#    ✓ Doc 559: 7 Khasiat Jeruk Bali Merah, Buah Tropis yang Kaya Zat Gizi...
#    ✓ Doc 561: 4 Resep Ketan Hitam Enak dan Sehat untuk Kudapan Saat Santai...
#    ✓ Doc 562: Kenali 9 Penyebab Perut Buncit dan Cara Mengatasinya...
#    ✓ Doc 563: Apakah Boleh Langsung Makan setelah Olahraga?...
#    ✓ Doc 567: 6 Menu Sarapan Vegan yang Sehat dan Tinggi Protein...
#    ✓ Doc 568: Panduan Lengkap Pola Makan Clean Eating...
#    ✓ Doc 569: Diet Golongan Darah AB, Ini Aturan dan Pro-Kontra...
#    ✓ Doc 574: Bisakah Diet Turunkan Berat Badan secara Drastis, tapi Tetap...
#    ✓ Doc 575: Apakah Orang yang Tidak Makan Nasi Hidupnya Lebih Sehat?...
#    ✓ Doc 576: 10 Manfaat Lingonberry yang Sayang untuk Dilewatkan...
#    ✓ Doc 577: Jam Berapa Saja Kita Harus Makan Saat Sedang Berdiet?...
#    ✓ Doc 578: 9 Makanan Rendah Kalori untuk Menurunkan Berat Badan...
#    ✓ Doc 579: Khasiat Minum Kuning Telur Campur Madu, Plus Risikonya...
#    ✓ Doc 580: Puasa Mutih, Inilah Manfaat, Risiko, dan Panduannya...
#    ✓ Doc 581: Inspirasi Menu Diet Defisit Kalori Selama Seminggu untuk Tur...
#    ✓ Doc 587: Surplus Kalori, Tambahan Kalori untuk Menaikkan Massa Otot...
#    ✓ Doc 590: Beras Merah vs Beras Shirataki, Mana yang Efektif untuk Diet...
#    ✓ Doc 591: 7 Manfaat Air Jahe dan Lemon, Bisa Turunkan Berat Badan...
#    ✓ Doc 592: Mengenal Ghrelin, Hormon Pengontrol Rasa Lapar...
#    ✓ Doc 593: 5 Manfaat Konsumsi Daging Ular dan Efek Sampingnya...
#    ✓ Doc 594: Sayang Dilewatkan, Ini 5 Manfaat Buah Naga untuk Diet...
#    ✓ Doc 595: Apakah Tidak Sarapan Pagi Bisa Menurunkan Berat Badan?...
#    ✓ Doc 596: Gastric Bypass...
#    ✓ Doc 598: 8 Manfaat Americano, Si Hitam Pahit yang Jadi Favorit...
#    ✓ Doc 602: Manfaat Asam Jawa untuk Diet, Apakah Ada?...
#    ✓ Doc 603: Mengenal 7 Manfaat Cuka Nanas yang Sayang Dilewatkan...
#    ✓ Doc 605: Cheat Day, Ketika Anda Libur Sejenak dari Diet...
#    ✓ Doc 606: Hati-Hati, 5 Buah-buahan Ini Justru Bisa Bikin Gemuk...
#    ✓ Doc 612: Apakah Benar Nanas Baik untuk Diet? Ini Penjelasannya...
#    ✓ Doc 613: 10 Manfaat Daun Talas dan Cara Tepat Mengolahnya...
#    ✓ Doc 614: 6 Makanan dengan Indeks Glikemik Tinggi yang Perlu Diwaspada...
#    ✓ Doc 615: Cayenne Pepper, Kenali Manfaat di Balik Rasa Pedasnya...
#    ✓ Doc 616: 5 Cara Menambah Nafsu Makan untuk Menaikkan Berat Badan...
#    ✓ Doc 621: Ketahui Pentingnya Menjaga Otot sejak Dewasa Muda agar Tubuh...
#    ✓ Doc 628: Kandungan Buah Apel dan Beragam Manfaat Mengonsumsinya...
#    ✓ Doc 629: Olahraga dan Makanan Sehat untuk Sixpack...
#    ✓ Doc 630: 7 Manfaat Air Es bagi Kesehatan...
#    ✓ Doc 633: 11 Manfaat Toge untuk Wanita yang Jarang Diketahui...
#    ✓ Doc 635: Kalori dalam Satu Buah Apel dan Cara Sehat Mengolahnya...
#    ✓ Doc 636: Manfaat Sarapan untuk Kesehatan...
#    ✓ Doc 637: 5 Manfaat Makanan Jepang bagi Kesehatan...
#    ✓ Doc 641: 10 Manfaat Cuka Apel untuk Kesehatan Tubuh...
#    ✓ Doc 647: Clean Eating, Inilah Panduan Lengkap Melakukannya...
#    ✓ Doc 651: 8 Lalapan dan Manfaatnya bagi Kesehatan...
#    ✓ Doc 653: 5 Manfaat Americano untuk Diet yang Sayang untuk Dilewatkan...
#    ✓ Doc 659: Manfaat Buah untuk Kesehatan yang Perlu Anda Ketahui...
#    ✓ Doc 661: Inilah Bahaya Kebanyakan Makan Alpukat yang Perlu Diketahui...
#    ✓ Doc 664: 6 Manfaat Daun Pakis bagi Kesehatan Tubuh...
#    ✓ Doc 665: Roti Tawar Putih, 5 Alasan Kenapa Konsumsinya Sebaiknya Diba...
#    ✓ Doc 678: Aneka Manfaat Adas untuk Kesehatan...
#    ✓ Doc 686: Amankah Mencuci Buah dan Sayur Menggunakan Sabun?...
#    ✓ Doc 688: 15 Manfaat Buah Naga untuk Kesehatan...
#    ✓ Doc 689: 6 Manfaat Anggur Hijau untuk Kesehatan...
#    ✓ Doc 698: Mangga Golek, Nutrisi dan Manfaatnya bagi Kesehatan...
#    ✓ Doc 700: Tak Sepahit Rasanya, Ini 5 Manfaat Pare yang Begitu Manis ba...
#    ✓ Doc 703: Ikan Gabus, Ketahui Kandungan Gizi, Manfaat, dan Cara Konsum...
#    ✓ Doc 706: 8 Manfaat Jus Kurma dan Pisang untuk Kesehatan...
#    ✓ Doc 715: Kebanyakan Makan Telur, Ini Dampak dan Batas Aman Mengonsums...
#    ✓ Doc 720: 12 Manfaat Semangka untuk Kesehatan...
#    ✓ Doc 723: 9 Manfaat Stroberi untuk Kesehatan Tubuh...
#    ✓ Doc 727: 8 Makanan Pengental Sperma Encer yang Bagus untuk Tingkatkan...
#    ✓ Doc 730: Pisang Raja, 7 Manfaatnya bagi Kesehatan Tubuh...
#    ✓ Doc 732: 4 Pemanis Buatan yang Aman dan Rendah Kalori...
#    ✓ Doc 740: 14 Manfaat Kacang Almond bagi Kesehatan...
#    ✓ Doc 746: Konyaku, Makanan Tinggi Serat yang Kaya Manfaat...
#    ✓ Doc 747: 4 Tips Mengolah Kentang Goreng Menjadi Lebih Sehat...
#    ✓ Doc 750: 7 Jenis Beras Paling Sehat dan Kaya Nutrisi...
#    ✓ Doc 752: Habis Makan Ngantuk, Ternyata Ini Penyebabnya...
#    ✓ Doc 753: Kenali Ragam Manfaat Acai Berry untuk Kesehatan...
#    ✓ Doc 754: Apakah Telur Rebus Bisa Menambah Berat Badan? Ini Jawabannya...
#    ✓ Doc 755: Asam Sitrat, Inilah Manfaatnya bagi Kesehatan...
#    ✓ Doc 759: Pepaya Muda, Ketahui Nutrisi, Manfaat, dan Cara Aman Mengons...
#    ✓ Doc 760: 10 Manfaat Minyak Ikan untuk Kesehatan...
#    ✓ Doc 761: Manfaat Kacang Pistachio untuk Diet, Solusi Alami Menurunkan...
#    ✓ Doc 763: Ketahui 5 Manfaat Buah Manggis untuk Kesehatan...
#    ✓ Doc 764: Daging Unta, Sumber Protein Rendah Lemak dengan Segudang Man...
#    ✓ Doc 768: Apel Malang, Kandungan Nutrisi dan Manfaatnya bagi Tubuh...
#    ✓ Doc 770: 7 Jus untuk Mengecilkan Perut yang Patut Dicoba...
#    ✓ Doc 772: 9 Manfaat Kacang Tanah untuk Pria yang Perlu Diketahui...
#    ✓ Doc 776: Bunda, Waspadai Bayimu Mengalami Gagal Tumbuh...
#    ✓ Doc 777: 7 Manfaat Rumput Laut dan Kandungan Nutrisi di Dalamnya...
#    ✓ Doc 778: 3 Bahaya Konsumsi Daging Mentah yang Perlu Diwaspadai...
#    ✓ Doc 781: 7 Zat Aditif pada Makanan yang Perlu Dihindari...
#    ✓ Doc 785: 6 Manfaat Terong bagi Kesehatan dan Cara Tepat Mengolahnya...
#    ✓ Doc 786: Gandum Utuh, Sumber Serat untuk Tubuh Sehat...
#    ✓ Doc 787: 6 Manfaat Tempe untuk Kesehatan yang Jarang Diketahui...
#    ✓ Doc 789: 8 Buah untuk Diabetes yang Baik Dikonsumsi...
#    ✓ Doc 792: Teh Melati, Ini Manfaatnya bagi Kesehatan...
#    ✓ Doc 797: 7 Manfaat Toge untuk Kesehatan dan Cara Mengolahnya yang Ben...
#    ✓ Doc 798: Ubi Rebus, Ketahui Kandungan Gizi dan Manfaatnya untuk Keseh...
#    ✓ Doc 799: Capsaicin, Senyawa Pedas dengan Beragam Khasiat...
#    ✓ Doc 802: 12 Pilihan Buah yang Mengandung Karbohidrat...
#    ✓ Doc 803: Coklat Putih, Kenali Manfaat dan Risiko Konsumsi Berlebih...
#    ✓ Doc 804: 10 Manfaat Minyak Zaitun untuk Kesehatan...
#    ✓ Doc 805: 6 Manfaat Kacang Pinus, dari Menurunkan Berat Badan sampai K...
#    ✓ Doc 808: 6 Manfaat Daging Sapi dan Tips Sehat Mengolahnya...
#    ✓ Doc 809: Mengenal Gula Rafinasi dan Perbedaannya dengan Gula Alami...
#    ✓ Doc 811: Inilah 6 Manfaat Buah Naga Putih bagi Kesehatan Tubuh...
#    ✓ Doc 813: 5 Manfaat Jahe bagi Kesehatan...
#    ✓ Doc 814: Piramida Makanan, Panduan Pola Makan Sehat dan Seimbang...
#    ✓ Doc 816: 8 Buah untuk Menurunkan Berat Badan...
#    ✓ Doc 818: Earl Grey Tea, Ketahui Manfaat, Efek Samping, dan Cara Mengo...
#    ✓ Doc 819: 9 Manfaat VCO yang Sayang untuk Dilewatkan...
#    ✓ Doc 822: Pola Makan Vegetarian yang Sehat...
#    ✓ Doc 823: Susu Pisang, Ini Ragam Manfaat dan Tips Mengonsumsinya...
#    ✓ Doc 825: Apakah Semangka Bagus untuk Diet? Ini Penjelasannya...
#    ✓ Doc 826: Pisang Mas, Inilah Kandungan Nutrisi dan Manfaatnya bagi Kes...
#    ✓ Doc 827: Mie Shirataki Bisa Menurunkan Berat Badan, Mitos atau Fakta?...
#    ✓ Doc 829: Manfaat Toge untuk Pria, Bisa Mencegah Stroke sampai Meningk...
#    ✓ Doc 842: 10 Manfaat Edamame untuk Wanita...
#    ✓ Doc 844: Kenali Manfaat Yoghurt untuk Diet dan Cara Memilihnya...
#    ✓ Doc 846: 5 Jenis Umbi-Umbian Populer Beserta Nutrisi dan Manfaatnya b...
#    ✓ Doc 847: Jamur Matsutake, Si Jamur Bernilai Tinggi dengan Segudang Ma...
#    ✓ Doc 848: 9 Manfaat Cuka yang Perlu Diketahui...
#    ✓ Doc 849: Mengenal Umbi Akar dan Manfaatnya untuk Kesehatan...
#    ✓ Doc 850: Ikan Pollock, Inilah 7 Manfaat dan Kandungan Nutrisinya...
#    ✓ Doc 853: Kalori Dada Ayam dan Tips Mengolahnya untuk Jadi Menu Diet S...
#    ✓ Doc 855: Jangan Ragu Lagi, Banyak Manfaat Alpukat untuk Ibu Hamil...
#    ✓ Doc 857: 9 Perbedaan Arabika dan Robusta yang Menarik untuk Diketahui...
#    ✓ Doc 858: Gluten Free, Begini Penjelasan dan Efek Sampingnya...
#    ✓ Doc 864: Kalori Ketoprak dan Cara Bijak Mengonsumsinya...
#    ✓ Doc 867: Mengenal Ikan Layang, Sumber Protein Hewani yang Enak, Ekono...
#    ✓ Doc 872: Mengenal Manfaat Karbohidrat Beserta Jenisnya...
#    ✓ Doc 875: Parsnip, Umbi-Umbian yang Kaya Manfaat dan Nutrisi...
#    ✓ Doc 876: Apakah Gorengan Bikin Gemuk? Ini Penjelasannya...
#    ✓ Doc 881: Segudang Manfaat Jus Apel dan Tomat bagi Kesehatan...
#    ✓ Doc 884: Metode Diet Water Fasting, Manfaat dan Bahayanya...
#    ✓ Doc 886: Tak Hanya Gurih, Ini 5 Manfaat Bawang Merah untuk Kesehatan ...
#    ✓ Doc 888: Daftar Makanan Bergizi untuk Ibu Hamil dan Manfaatnya...
#    ✓ Doc 891: Manfaat Sarapan yang Tidak Boleh Dilewatkan...
#    ✓ Doc 896: 7 Makanan Booster ASI yang Bisa Busui Coba...
#    ✓ Doc 897: Daging Kuda, Inilah Kandungan Nutrisi dan Manfaatnya bagi Ke...
#    ✓ Doc 904: 8 Khasiat Hebat Teh Oolong untuk Kesehatan...
#    ✓ Doc 905: Mengenal Indeks Glikemik dan Pengaruhnya pada Pola Makan Seh...
#    ✓ Doc 909: Buah Naga untuk Asam Lambung, Apakah Aman? Ini Jawabannya...
#    ✓ Doc 923: 5 Beras Shirataki Terbaik yang Sehat dan Rendah Kalori...
#    ✓ Doc 926: Gadung, Umbi-Umbian yang Kaya Nutrisi dan Manfaat...
#    ✓ Doc 927: Berbagai Manfaat Buah Berwarna Ungu yang Jarang Diketahui...
#    ✓ Doc 930: 6 Manfaat Buah Plum bagi Kesehatan...
#    ✓ Doc 931: Ikan Baronang, Ketahui 7 Manfaatnya bagi Tubuh...
#    ✓ Doc 935: Jangan Lewatkan 5 Manfaat Ikan Mujair bagi Kesehatan...
#    ✓ Doc 937: 7 Manfaat Apel Fuji untuk Kesehatan Tubuh...
#    ✓ Doc 941: Kalori Nasi Goreng dan Tips Mengonsumsinya agar Lebih Sehat...
#    ✓ Doc 943: 8 Manfaat Kafein untuk Kesehatan...
#    ✓ Doc 944: Daun Kelor, Manfaat hingga Tips Mengolahnya...
#    ✓ Doc 949: 9 Manfaat Daun Bawang yang Tak Hanya sebagai Taburan Masakan...
#    ✓ Doc 950: Cara Mengonsumsi Chia Seed yang Tepat untuk Peroleh Manfaatn...
#    ✓ Doc 952: Ikan Kakatua, Ketahui Nutrisi dan Manfaat di Balik Warna Can...
#    ✓ Doc 958: 6 Susu Penambah Berat Badan yang Efektif...
#    ✓ Doc 960: Makanan Berkalori Tinggi, Ketahui Dampak untuk Tubuh hingga ...
#    ✓ Doc 961: 11 Manfaat Makan Telur Rebus yang Sayang untuk Dilewatkan...
#    ✓ Doc 962: Faktor Penyebab Badan Kurus dan Tips Sehat untuk Mengatasiny...
#    ✓ Doc 967: 8 Camilan Sehat agar Tubuh Tetap Langsing...
#    ✓ Doc 968: 7 Manfaat Minyak Jintan Hitam untuk Kesehatan...
#    ✓ Doc 983: 6 Manfaat Lemak Tak Jenuh untuk Kesehatan...
#    ✓ Doc 984: Makan Ceker Ayam, Sehat atau Tidak?...
#    ✓ Doc 986: Manfaat Jus Seledri dan Timun yang Baik untuk Kesehatan Tubu...
#    ✓ Doc 987: 5 Manfaat Daging Ayam dan Tips Mengolahnya yang Tepat...
#    ✓ Doc 988: 10 Snack Sehat yang Lezat dan Praktis...
#    ✓ Doc 989: Ketahui Manfaat Makan Buah sebelum Makan...
#    ✓ Doc 990: 6 Pilihan Makanan Sehat yang Perlu Dikonsumsi Setiap Hari...
#    ✓ Doc 991: Kalori Lontong Sayur dan Tips Menikmatinya dengan Cara Sehat...
#    ✓ Doc 993: 8 Manfaat Jamur Tiram dan Cara Mengolahnya...
#    ✓ Doc 994: 7 Manfaat Labu Siam Rebus yang Baik untuk Kesehatan...
#    ✓ Doc 997: Kacang Roay, Ketahui Nutrisi dan Manfaatnya bagi kesehatan...
#    ✓ Doc 999: Jus Plum, Ini Manfaat dan Cara Membuatnya di Rumah...
#    ✓ Doc 1004: Ikan Tapah, Ketahui Manfaat dan Cara Mengonsumsinya...
#    ✓ Doc 1006: Nasi Goreng Sehat, Begini Cara Membuatnya...
#    ✓ Doc 1009: Mengenali Kalori Sebagai Kunci Berat Badan Sehat...
#    ✓ Doc 1014: 5 Manfaat Teh Daun Jati Cina untuk Kesehatan...
#    ✓ Doc 1015: Bukan Cuma yang Manis, Kenali Makanan yang Meningkatkan Gula...
#    ✓ Doc 1016: Keong Macan, Inilah Manfaat dan Cara Mengolahnya...
#    ✓ Doc 1017: Cara Mengonsumsi Jus Sehat agar Manfaatnya Optimal...
#    ✓ Doc 1023: Nori, Rumput Laut yang Lezat dan Penuh Manfaat...
#    ✓ Doc 1026: 6 Manfaat Buah Melon untuk Wanita yang Jarang Diketahui...
#    ✓ Doc 1027: Sejumlah Manfaat Buah Lingonberry bagi Kesehatan...
#    ✓ Doc 1028: 8 Manfaat Kentang Rebus yang Patut Dilirik...
#    ✓ Doc 1030: 10 Manfaat Susu Kedelai untuk Pria yang Jarang Diketahui...
#    ✓ Doc 1033: Kyuri, Timun Jepang yang Kaya Manfaat...
#    ✓ Doc 1034: Ikan Makarel, Ketahui Manfaat Serta Tips Memilih dan Mengola...
#    ✓ Doc 1037: 12 Manfaat Kacang Tanah Rebus untuk Kesehatan yang Sayang Di...
#    ✓ Doc 1039: 9 Manfaat Daun Ubi Jalar untuk Kesehatan Tubuh...
#    ✓ Doc 1040: Kenali Beberapa Tanda Kekurangan Vitamin E...
#    ✓ Doc 1045: Keuntungan dan Risiko Mengonsumsi Sakarin...
#    ✓ Doc 1047: Ikan Kembung, Ketahui Kandungan Gizi, Manfaat, dan Cara Meng...
#    ✓ Doc 1050: Ikan Kakap, Inilah Kandungan Nutrisi dan Manfaatnya...
#    ✓ Doc 1051: 16 Manfaat Buah Nanas bagi Kesehatan...
#    ✓ Doc 1052: 7 Manfaat Keju untuk Kesehatan...
#    ✓ Doc 1053: 4 Manfaat Cuka Nanas dan Cara Membuatnya Sendiri di Rumah...
#    ✓ Doc 1058: Ikan Mahi-Mahi, Ini Kandungan Gizi dan Manfaatnya untuk Kese...
#    ✓ Doc 1059: 7 Manfaat Kentang dan Cara Tepat Mengolahnya...
#    ✓ Doc 1061: Diet TKTP, Inilah Cara Melakukannya yang Aman dan Efektif...
#    ✓ Doc 1068: 8 Manfaat Saffron bagi Kesehatan...
#    ✓ Doc 1070: Buah Prune, Inilah Nutrisi dan Manfaatnya yang Sayang Dilewa...
#    ✓ Doc 1075: 8 Manfaat Semangka Kuning yang Sayang Dilewatkan...
#    ✓ Doc 1087: Roti Sourdough, Ketahui Nutrisi dan Manfaatnya bagi Kesehata...
#    ✓ Doc 1088: Minyak Biji Bunga Matahari, Ketahui Nutrisi serta Manfaatnya...
#    ✓ Doc 1089: Makanan yang Sering Dianggap Mengganggu Kesehatan Ini, Terny...
#    ✓ Doc 1090: 10 Pilihan Jus untuk Meningkatkan Hb yang Jarang Diketahui...
#    ✓ Doc 1095: 10 Cemilan untuk Diet yang Bantu Turunkan Berat Badan...
#    ✓ Doc 1097: Cuka Putih, Ketahui Manfaat dan Cara Penggunaannya...
#    ✓ Doc 1099: 9 Manfaat Oatmeal untuk Kesehatan...
#    ✓ Doc 1100: 6 Manfaat Jus Apel untuk Kesehatan yang Senikmat Rasanya...
#    ✓ Doc 1101: 10 Manfaat Cokelat dan Tips Aman Mengonsumsinya...
#    ✓ Doc 1102: Mengenal Daun Stevia, Pemanis Alami Pengganti Gula...
#    ✓ Doc 1109: Kalori Tahu Rebus, Pilihan Tepat untuk Diet Rendah Lemak dan...
#    ✓ Doc 1128: 10 Manfaat Singkong Rebus yang Jarang Dibicarakan...
#    ✓ Doc 1134: Jus Kiwi, Ini Manfaat dan Tips Membuatnya...
#    ✓ Doc 1136: 12 Makanan Penambah Hb (Hemoglobin) Darah...
#    ✓ Doc 1137: Lemak Tak Jenuh Ganda, Inilah Manfaat dan Sumber Makanannya...
#    ✓ Doc 1140: Manfaat Gula Batu dan Risiko di Balik Rasa Manisnya...
#    ✓ Doc 1141: 6 Manfaat Buah Pir untuk Kesehatan...
#    ✓ Doc 1147: 3 Manfaat Bunga Pepaya bagi Kesehatan dan Cara Mengolahnya...
#    ✓ Doc 1154: 6 Manfaat Ikan Mas untuk Kesehatan...
#    ✓ Doc 1157: Manfaat Tomat untuk Pria, Mencegah Penyakit Jantung sampai M...
#    ✓ Doc 1158: 5 Cara Mengatasi Berat Badan Kurang pada Anak...
#    ✓ Doc 1159: 9 Manfaat Alpukat untuk Kesehatan...
#    ✓ Doc 1160: Kalori Ubi Rebus dan Tips Mengonsumsinya...
#    ✓ Doc 1161: 3 Mitos Cuka Apel dan Fakta di Baliknya...
#    ✓ Doc 1162: 6 Cara Mengonsumsi Cuka Apel yang Perlu Diperhatikan...
#    ✓ Doc 1164: 10 Buah untuk Ginjal yang Menyehatkan...
#    ✓ Doc 1168: 6 Jenis Makanan untuk Ibu Hamil Trimester Pertama...
#    ✓ Doc 1169: Horseradish, Inilah Nutrisi, Manfaat, dan Cara Mengonsumsiny...
#    ✓ Doc 1172: 5 Makanan Penetral setelah Makan Daging yang Efektif...
#    ✓ Doc 1173: Pir Hijau, Inilah Nutrisi dan Manfaatnya untuk Kesehatan...
#    ✓ Doc 1175: 8 Manfaat Terong bagi Wanita yang Sayang Dilewatkan...
#    ✓ Doc 1176: Seputar Profesi Dokter Spesialis Gizi dan Perannya dalam Dun...
#    ✓ Doc 1179: 8 Makanan Bebas Gluten untuk Menu Sehari-hari...
#    ✓ Doc 1183: Jenis Vitamin Penambah Berat Badan dan Nutrisi Lain yang Men...
#    ✓ Doc 1184: Seperti Ini Diet Cepat Kurus Alami yang Tahan Lama...
#    ✓ Doc 1186: 10 Penyebab Sering Lapar dan Cara Mengatasinya...
#    ✓ Doc 1188: Saus Tiram: Manfaat, Cara Memilih, dan Tips Aman Mengonsumsi...
#    ✓ Doc 1189: 11 Risiko Sering Makan Jeroan...
#    ✓ Doc 1193: Ikan Toman, Ini Kandungan Gizi dan Manfaatnya untuk Kesehata...
#    ✓ Doc 1198: Sarapan dengan Buah, Apakah Bagus untuk Kesehatan?...
#    ✓ Doc 1202: Cara Menurunkan Berat Badan Dalam 1 Minggu Secara Alami...
#    ✓ Doc 1209: 10 Manfaat Kacang Kenari dan Beragam Kandungan di Dalamnya...
#    ✓ Doc 1218: Stevia untuk Minuman, Cara Mudah Kurangi Asupan Gula...
#    ✓ Doc 1219: Ikan Wader, Nutrisi dan Manfaatnya yang Beragam...
#    ✓ Doc 1224: Jamur Merang, Ketahui Kandungan Nutrisi dan Manfaatnya bagi ...
#    ✓ Doc 1230: Kelengkeng Merah, Inilah Kandungan Nutrisi dan Manfaatnya ba...
#    ✓ Doc 1231: Mengenal Pola Makan Food Combining...
#    ✓ Doc 1233: 9 Manfaat Buah Gandaria yang Jarang Diketahui...
#    ✓ Doc 1237: 7 Manfaat Pisang Kepok yang Sayang untuk Dilewatkan...
#    ✓ Doc 1244: Mangga Manalagi, Ini Ragam Manfaatnya untuk Kesehatan...
#    ✓ Doc 1246: 9 Manfaat Kopi Hitam bagi Kesehatan Tubuh...
#    ✓ Doc 1249: Mengenal Pola Makan Pescatarian dan Manfaatnya bagi Kesehata...
#    ✓ Doc 1250: 10 Manfaat Tomat untuk Wanita, Bukan Cuma Bikin Kulit Cerah!...
#    ✓ Doc 1254: 12 Manfaat Buah Naga Merah untuk Kesehatan...
#    ✓ Doc 1264: 6 Manfaat Buah Leci untuk Kesehatan Tubuh...
#    ✓ Doc 1269: Hojicha, Inilah Nutrisi dan Manfaatnya bagi Kesehatan...
#    ✓ Doc 1271: Inilah 10 Manfaat Salak untuk Kesehatan...
#    ✓ Doc 1274: Yuk, Mengenal Biji Rami dan Manfaatnya untuk Kesehatan...
#    ✓ Doc 1276: 9 Manfaat Minum Teh Tanpa Gula untuk Kesehatan Tubuh...
#    ✓ Doc 1278: Jambu Kristal, Inilah Kandungan Nutrisi dan Manfaatnya bagi ...
#    ✓ Doc 1282: Matcha, Segudang Manfaat di Balik Rasa Pahitnya...
#    ✓ Doc 1284: Perbedaan Daging Sapi dan Kambing yang Perlu Dipahami...
#    ✓ Doc 1287: Fenilalanin, Ketahui Manfaat dan Fungsinya bagi Tubuh...
#    ✓ Doc 1289: 10 Manfaat Jamur Kuping bagi Kesehatan yang Sayang Dilewatka...
#    ✓ Doc 1290: 3 Manfaat Daun Singkong dan Cara Mengolahnya...
#    ✓ Doc 1291: 10 Makanan Fermentasi dan Manfaatnya bagi Tubuh...
#    ✓ Doc 1295: 12 Manfaat Teh Hijau untuk Kesehatan...
#    ✓ Doc 1296: 9 Manfaat Telur Asin yang Jarang Diketahui...
#    ✓ Doc 1297: 7 Jenis Sereal untuk Diet yang Sehat dan Mengenyangkan...
#    ✓ Doc 1298: 9 Manfaat Jus Jeruk yang Segarkan Harimu...
#    ✓ Doc 1301: Jangan Putus Asa, Ada Banyak Cara Menahan Nafsu Makan...
#    ✓ Doc 1303: Dampak Kekurangan Karbohidrat dan Cara Mengatasinya...
#    ✓ Doc 1306: Daftar Makanan Berserat Sehari-hari dan Manfaatnya bagi Kese...
#    ✓ Doc 1311: 8 Manfaat Jeruk Limau untuk Kesehatan...
#    ✓ Doc 1312: 8 Manfaat Air Kelapa Hijau bagi Kesehatan...
#    ✓ Doc 1313: Manfaat Protein dan Sumbernya...
#    ✓ Doc 1320: Cara Membuat Minyak Kelapa Sendiri di Rumah...
#    ✓ Doc 1321: Tak Hanya Nikmat, Inilah 7 Manfaat Pisang Tanduk bagi Keseha...
#    ✓ Doc 1323: Dampak Aspartam bagi Kesehatan Tubuh jika Dikonsumsi Berlebi...
#    ✓ Doc 1324: 6 Manfaat Ubi Cilembu, Mulai dari Atasi Sembelit hingga Cega...
#    ✓ Doc 1325: 11 Menu Sarapan Sebelum Olahraga Pagi yang Baik Dikonsumsi...
#    ✓ Doc 1327: 7 Manfaat Kembang Kol bagi Kesehatan Tubuh...
#    ✓ Doc 1331: Ragam Sayuran Berwarna Kuning dan Manfaatnya untuk Kesehatan...
#    ✓ Doc 1337: 8 Manfaat Minyak Zaitun untuk Wanita...
#    ✓ Doc 1339: 7 Manfaat Pecel Sayur untuk Kesehatan...
#    ✓ Doc 1341: Vegetarian, Kenali Jenis hingga Manfaat dari Pola Makan Ini...
#    ✓ Doc 1344: Mangga Udang, Ini Kandungan Nutrisi dan Manfaatnya bagi Kese...
#    ✓ Doc 1345: Seputar Whey Protein dan Manfaatnya bagi Kesehatan...
#    ✓ Doc 1349: Haruskah Sarapan sebelum Olahraga? Ini Jawabannya...
#    ✓ Doc 1352: Mangga Gedong, Inilah Kandungan Nutrisi, Manfaat, dan Cara M...
#    ✓ Doc 1356: 4 Manfaat Ngemil untuk Tubuh yang Perlu Diketahui...
#    ✓ Doc 1357: 11 Manfaat Buah Kersen bagi Kesehatan Tubuh...
#    ✓ Doc 1358: Ketahui Kalori Keripik Pisang dan Cara Sehat Mengonsumsinya...
#    ✓ Doc 1359: Benarkah Makanan Pedas Bisa Turunkan Berat Badan?...
#    ✓ Doc 1361: 5 Manfaat Edamame untuk Kesehatan Tubuh...
#    ✓ Doc 1362: Daging Kerbau, Inilah Kandungan Nutrisi, Manfaat, dan Tips A...
#    ✓ Doc 1363: Efek Makan Buah Malam Hari, Bisa Bagus maupun Tidak...
#    ✓ Doc 1364: 5 Bahaya Minuman Manis terhadap Kesehatan...
#    ✓ Doc 1365: Kendalikan Kadar Gula Darah dengan Stevia...
#    ✓ Doc 1368: 7 Buah untuk Menaikkan Trombosit...
#    ✓ Doc 1370: Ikan Belida, Sumber Protein Air Tawar yang Lezat dan Kaya Ma...
#    ✓ Doc 1372: Kubis Brussel, Sayuran Kecil dengan Segudang Nutrisi...
#    ✓ Doc 1379: Nasi Jagung, Alternatif Nasi yang Menyehatkan...
#    ✓ Doc 1380: Kalori Salad Buah dan Cara Sehat Menyajikannya...
#    ✓ Doc 1381: Anjuran Ahli Gizi Terkait Pola Makan Sehat dan Tepat...
#    ✓ Doc 1382: Manfaat Cold Pressed Juice, dari Hidrasi Tubuh hingga Menjag...
#    ✓ Doc 1385: 10 Manfaat Jus Semangka, Tak Kalah Manis dengan Rasanya...
#    ✓ Doc 1389: 10 Buah Penurun Tensi yang Mudah Ditemukan...
#    ✓ Doc 1391: Mangga Kweni, Inilah Nutrisi, Manfaat, dan Cara Mengonsumsin...
#    ✓ Doc 1393: Kentos Kelapa, Ketahui Kandungan Nutrisi dan Ragam Manfaatny...
#    ✓ Doc 1396: 9 Makanan Probiotik dan Manfaatnya untuk Tubuh...
#    ✓ Doc 1401: 7 Manfaat Buah Naga untuk Wanita yang Penting Diketahui...
#    ✓ Doc 1402: Jeroan: Manfaat, Risiko, dan Tips Aman Mengonsumsinya...
#    ✓ Doc 1408: 7 Manfaat Daun Talas dan Cara Mengolahnya yang Aman...
#    ✓ Doc 1413: 7 Manfaat Buah Pace dan Efek Sampingnya untuk Kesehatan...
#    ✓ Doc 1415: 9 Makanan Penurun Gula Darah yang Cepat dan Efektif...
#    ✓ Doc 1419: 7 Pilihan Menu Sarapan Pagi yang Sehat, Lezat, dan Nikmat...
#    ✓ Doc 1420: 7 Manfaat Kecambah dan Cara Aman Mengonsumsinya...
#    ✓ Doc 1421: Mangga Indramayu, Inilah Nutrisi dan Manfaatnya bagi Kesehat...
#    ✓ Doc 1430: Ikan Manyung, Ini Manfaat dan Cara Aman Mengonsumsinya...
#    ✓ Doc 1431: 10 Makanan yang Dibenci Sel Kanker tetapi Baik untuk Tubuh...
#    ✓ Doc 1432: 7 Manfaat Teh Hitam untuk Kesehatan...
#    ✓ Doc 1435: 8 Cara Makan Buah yang Sehat Agar Manfaatnya Maksimal...
#    ✓ Doc 1436: Apakah Mangga Bagus untuk Diet? Ini Jawabannya...
#    ✓ Doc 1437: 6 Manfaat Rebung dan Cara Mengolahnya...
#    ✓ Doc 1438: 8 Manfaat Jus Buah Naga untuk Kesehatan...
#    ✓ Doc 1439: 11 Manfaat Kacang Tanah bagi Kesehatan Tubuh...
#    ✓ Doc 1447: 8 Manfaat Pisang bagi Kesehatan Tubuh...
#    ✓ Doc 1450: 9 Manfaat Labu Siam untuk Kesehatan Tubuh...
#    ✓ Doc 1451: Menu Diet Defisit Kalori yang Sehat dan Tetap Enak...
#    ✓ Doc 1453: Memahami Label Nutrisi pada Produk Kemasan...
#    ✓ Doc 1454: 9 Manfaat Sayuran Hijau untuk Kesehatan...
#    ✓ Doc 1461: 7 Manfaat Buah Duku untuk Pria yang Wajib Diketahui...
#    ✓ Doc 1462: Kerang Simping, Inilah Manfaat dan Cara Mengolahnya...
#    ✓ Doc 1466: Rebon, Si Mungil yang Kaya Manfaat...
#    ✓ Doc 1468: Makanan untuk Program Hamil yang Sukses...
#    ✓ Doc 1469: 7 Manfaat Lemon untuk Kesehatan yang Perlu Diketahui...
#    ✓ Doc 1473: Surplus Kalori, Dampaknya bagi Tubuh dan Cara Melakukannya d...
#    ✓ Doc 1482: 8 Manfaat Buah Menteng untuk Kesehatan yang Jarang Diketahui...
#    ✓ Doc 1487: 7 Manfaat Buah Lontar untuk Kesehatan...
#    ✓ Doc 1489: Apakah Alpukat Bisa Menambah Berat Badan? Ini Jawabannya...
#    ✓ Doc 1490: 6 Manfaat Ikan Layur bagi Kesehatan yang Jarang Diketahui...
#    ✓ Doc 1491: Inilah 6 Manfaat Ikan Tuna bagi Kesehatan Tubuh...
#    ✓ Doc 1495: Prebiotik, Serat Spesial yang Kaya akan Manfaat...
#    ✓ Doc 1496: Susu Protein untuk Diet sebagai Pilihan Sehat Saat Menurunka...
#    ✓ Doc 1499: Keju Edam, Inilah Kandungan Nutrisi dan Berbagai Potensi Man...
#    ✓ Doc 1502: 8 Jus untuk Asam Lambung yang Aman dan Efektif Atasi Keluhan...
#    ✓ Doc 1503: Manfaat Nasi Merah dan Tips Mengonsumsinya...
#    ✓ Doc 1504: Minum Teh setelah Makan, Ini Dampaknya pada Tubuh...
#    ✓ Doc 1506: Manfaat dan Panduan Menjalani Diet Mediterania...
#    ✓ Doc 1511: 7 Susu Nabati yang Lezat dan Bernutrisi...
#    ✓ Doc 1512: Selada Merah, Ketahui Nutrisi dan Manfaatnya bagi Kesehatan...
#    ✓ Doc 1514: Gelato, Ketahui Kandungan, Manfaat, dan Cara Tepat Mengonsum...
#    ✓ Doc 1517: Tempe Kacang Hijau, Inilah Kandungan Nutrisi, Manfaat, dan C...
#    ✓ Doc 1522: 5 Manfaat Susu Kambing untuk Kesehatan...
#    ✓ Doc 1524: 6 Manfaat Belimbing untuk Kesehatan Tubuh...
#    ✓ Doc 1526: Scallop: Kandungan Gizi, Manfaat, dan Cara Memasaknya...
#    ✓ Doc 1529: 9 Manfaat Teh Honeybush untuk Kesehatan yang Patut Dilirik...
#    ✓ Doc 1534: Antosianin, Senyawa dalam Buah dan Sayur dengan Banyak Manfa...
#    ✓ Doc 1535: Kalori Jagung Rebus dan Manfaatnya untuk Kesehatan...
#    ✓ Doc 1537: 6 Manfaat Selada bagi Kesehatan Tubuh...
#    ✓ Doc 1539: Americano, Kenali Manfaat dan Efek Sampingnya...
#    ✓ Doc 1540: 6 Makanan Protein untuk Diet...
#
# ...
#    ✓ Doc 587: Surplus Kalori, Tambahan Kalori untuk Menaikkan Massa Otot...
#    ✓ Doc 592: Mengenal Ghrelin, Hormon Pengontrol Rasa Lapar...
#    ✓ Doc 595: Apakah Tidak Sarapan Pagi Bisa Menurunkan Berat Badan?...
#    ✓ Doc 599: 5 Resep Brunch Lezat, Buat Anda yang Suka Sarapan Siang-Sian...
#    ✓ Doc 606: Hati-Hati, 5 Buah-buahan Ini Justru Bisa Bikin Gemuk...
#    ✓ Doc 608: Daftar Manfaat Omega-3, 6, dan 9 yang Penting bagi Tubuh...
#    ✓ Doc 616: 5 Cara Menambah Nafsu Makan untuk Menaikkan Berat Badan...
#    ✓ Doc 630: 7 Manfaat Air Es bagi Kesehatan...
#    ✓ Doc 638: 9 Manfaat Ketan Hitam bagi Kesehatan...
#    ✓ Doc 644: Bolehkah Bayi Mengonsumsi Jamur?...
#    ✓ Doc 663: 11 Makanan Mengandung Kalsium yang Mudah Didapatkan...
#    ✓ Doc 672: 12 Manfaat Bayam untuk Kesehatan Tubuh...
#    ✓ Doc 680: Susu Gandum, Inilah Nutrisi dan Manfaatnya bagi Kesehatan...
#    ✓ Doc 682: Ikan Sepat, Inilah Kandungan Nutrisi dan Manfaatnya bagi Kes...
#    ✓ Doc 683: Oyong, Ketahui Kandungan, Manfaat, dan Cara Mengonsumsinya...
#    ✓ Doc 691: Jangan Biarkan Anak Terlalu Banyak Minum Susu, Ini Risikonya...
#    ✓ Doc 703: Ikan Gabus, Ketahui Kandungan Gizi, Manfaat, dan Cara Konsum...
#    ✓ Doc 704: Kenali Kandungan Nutrisi dalam Segelas Susu dan Manfaatnya b...
#    ✓ Doc 717: Ikan Sembilang, Kandungan Gizi, Manfaat, dan Tips Mengonsums...
#    ✓ Doc 719: Manfaat Belut untuk Kesehatan, Bisa Mencegah Infeksi sampai ...
#    ✓ Doc 740: 14 Manfaat Kacang Almond bagi Kesehatan...
#    ✓ Doc 751: Black Sapote, Inilah Manfaat dan Tips Aman Mengonsumsinya...
#    ✓ Doc 754: Apakah Telur Rebus Bisa Menambah Berat Badan? Ini Jawabannya...
#    ✓ Doc 756: 8 Manfaat Baking Soda yang Jarang Diketahui...
#    ✓ Doc 764: Daging Unta, Sumber Protein Rendah Lemak dengan Segudang Man...
#    ✓ Doc 771: Minum Teh Setelah Makan Daging, Boleh atau Tidak?...
#    ✓ Doc 776: Bunda, Waspadai Bayimu Mengalami Gagal Tumbuh...
#    ✓ Doc 782: Ikan Betok, Kandungan Gizi, Manfaat, dan Tips Pengolahannya...
#    ✓ Doc 785: 6 Manfaat Terong bagi Kesehatan dan Cara Tepat Mengolahnya...
#    ✓ Doc 795: 5 Manfaat Minum Cuka Apel sebelum Tidur dan Risiko di Balikn...
#    ✓ Doc 800: Sumber Protein Hewani Terbaik untuk MPASI...
#    ✓ Doc 802: 12 Pilihan Buah yang Mengandung Karbohidrat...
#    ✓ Doc 803: Coklat Putih, Kenali Manfaat dan Risiko Konsumsi Berlebih...
#    ✓ Doc 805: 6 Manfaat Kacang Pinus, dari Menurunkan Berat Badan sampai K...
#    ✓ Doc 808: 6 Manfaat Daging Sapi dan Tips Sehat Mengolahnya...
#    ✓ Doc 812: 10 Makanan yang Mengandung Omega 3...
#    ✓ Doc 815: Ketahui Kebutuhan Protein Harian yang Perlu Dipenuhi Setiap ...
#    ✓ Doc 822: Pola Makan Vegetarian yang Sehat...
#    ✓ Doc 831: 5 Manfaat Daun Jeruk untuk Kesehatan yang Jarang Diketahui...
#    ✓ Doc 836: 10 Manfaat Susu Kambing Etawa dan Kelebihannya Dibandingkan ...
#    ✓ Doc 839: Menguak Manfaat Susu Unta yang Menyehatkan...
#    ✓ Doc 841: 5 Manfaat Bawang Merah Mentah yang Sayang untuk Dilewatkan...
#    ✓ Doc 847: Jamur Matsutake, Si Jamur Bernilai Tinggi dengan Segudang Ma...
#    ✓ Doc 858: Gluten Free, Begini Penjelasan dan Efek Sampingnya...
#    ✓ Doc 859: Ikan Marlin, Ini Kandungan Nutrisi dan Manfaat Kesehatannya...
#    ✓ Doc 860: Manfaat Bubur Kacang Hijau yang Nyaman di Perut...
#    ✓ Doc 863: Kenali Bahaya Makanan Siap Saji yang Bisa Mengintai Anda...
#    ✓ Doc 867: Mengenal Ikan Layang, Sumber Protein Hewani yang Enak, Ekono...
#    ✓ Doc 870: Ikan Sidat, Ini Kandungan Gizi dan Manfaatnya untuk Kesehata...
#    ✓ Doc 871: 4 Manfaat Telur Setengah Matang dan Tips Aman Mengonsumsinya...
#    ✓ Doc 876: Apakah Gorengan Bikin Gemuk? Ini Penjelasannya...
#    ✓ Doc 879: 6 Manfaat Kuning Telur dan Tips Sehat Mengonsumsinya...
#    ✓ Doc 880: 7 Sumber Makanan Omega-6 yang Baik Dikonsumsi...
#    ✓ Doc 890: Daging Biawak, Ketahui Manfaat dan Risiko Mengonsumsinya...
#    ✓ Doc 891: Manfaat Sarapan yang Tidak Boleh Dilewatkan...
#    ✓ Doc 892: Mengenal Susu Ibu Hamil, Pelengkap Nutrisi Kehamilan Bumil...
#    ✓ Doc 893: Ikan Baung, Inilah Manfaat dan Tips Mengolahnya...
#    ✓ Doc 894: Nasi Tim, Inilah Manfaat dan Tips Membuatnya yang Sehat...
#    ✓ Doc 896: 7 Makanan Booster ASI yang Bisa Busui Coba...
#    ✓ Doc 898: Burung Puyuh, Sumber Protein Hewani yang Menyehatkan Tubuh...
#    ✓ Doc 910: Manfaat Kangen Water untuk Kesehatan, Ini Faktanya...
#    ✓ Doc 912: Probiotik, Kenali Jenis Bakteri dan Manfaatnya...
#    ✓ Doc 915: Biji Teratai, Camilan Sehat dengan Segudang Manfaat...
#    ✓ Doc 916: Pilihan Makanan untuk Anak Diare, Penting Diketahui Orangtua...
#    ✓ Doc 918: Ketahui Risiko dan Manfaat Hati Sapi...
#    ✓ Doc 920: 5 Manfaat Kangkung yang Sayang Dilewatkan...
#    ✓ Doc 922: Buah Malaka, Kenali Manfaat dan Risiko di Baliknya...
#    ✓ Doc 928: Manfaat Sari Kurma untuk Asam Lambung dan Cara Mudah Membuat...
#    ✓ Doc 936: Sandwich Buah, Camilan Bernutrisi yang Menyehatkan Tubuh...
#    ✓ Doc 939: Benarkah Konsumsi Gula Berlebih Picu Anak Hiperaktif?...
#    ✓ Doc 940: Beta Karoten Alami untuk Menyehatkan Mata dan Tubuh...
#    ✓ Doc 945: 8 Manfaat Teh Chamomile bagi Kesehatan...
#    ✓ Doc 946: Ikan Barakuda, Ini Kandungan Gizi dan Manfaatnya untuk Keseh...
#    ✓ Doc 954: Ikan Sapu-Sapu, Ini Kandungan Gizi dan Manfaatnya untuk Kese...
#    ✓ Doc 955: Tips Diet Rendah Garam yang Aman dan Tepat...
#    ✓ Doc 961: 11 Manfaat Makan Telur Rebus yang Sayang untuk Dilewatkan...
#    ✓ Doc 962: Faktor Penyebab Badan Kurus dan Tips Sehat untuk Mengatasiny...
#    ✓ Doc 964: Begini Membentuk Pola Makan Sehat Balita...
#    ✓ Doc 970: 5 Makanan Sumber Protein Hewani yang Dapat Dikonsumsi...
#    ✓ Doc 974: Kalori Cireng dan Tips Mengonsumsinya dengan Sehat...
#    ✓ Doc 975: Seputar Penyakit Busung Lapar, Penyebab dan Perawatannya...
#    ✓ Doc 978: Protein Daging Sapi dan Cara Tepat Memaksimalkan Manfaatnya...
#    ✓ Doc 982: Sarapan Sereal, Menu Sehat dan Praktis untuk Memulai Hari...
#    ✓ Doc 984: Makan Ceker Ayam, Sehat atau Tidak?...
#    ✓ Doc 985: 7 Buah yang Mengandung Vitamin E dan Manfaatnya...
#    ✓ Doc 996: 9 Manfaat Garam untuk Kesehatan yang Perlu Diketahui...
#    ✓ Doc 1002: 9 Manfaat Jambu Biji bagi Kesehatan Tubuh...
#    ✓ Doc 1004: Ikan Tapah, Ketahui Manfaat dan Cara Mengonsumsinya...
#    ✓ Doc 1014: 5 Manfaat Teh Daun Jati Cina untuk Kesehatan...
#    ✓ Doc 1021: 5 Fungsi Protein yang Penting bagi Tubuh...
#    ✓ Doc 1025: Fungsi Mineral Berdasarkan Jenis-Jenisnya...
#    ✓ Doc 1037: 12 Manfaat Kacang Tanah Rebus untuk Kesehatan yang Sayang Di...
#    ✓ Doc 1038: 6 Makanan Sumber Protein Nabati yang Baik untuk Anak...
#    ✓ Doc 1040: Kenali Beberapa Tanda Kekurangan Vitamin E...
#    ✓ Doc 1042: Daging Ular Bagus untuk Kulit, Ini Fakta Medisnya...
#    ✓ Doc 1044: Protein Susu Kedelai, Ini Jumlah dan Manfaatnya bagi Tubuh...
#    ✓ Doc 1045: Keuntungan dan Risiko Mengonsumsi Sakarin...
#    ✓ Doc 1047: Ikan Kembung, Ketahui Kandungan Gizi, Manfaat, dan Cara Meng...
#    ✓ Doc 1049: DHA, Ketahui 9 Manfaatnya untuk Kesehatan Tubuh...
#    ✓ Doc 1052: 7 Manfaat Keju untuk Kesehatan...
#    ✓ Doc 1055: 9 Makanan Peninggi Badan yang Patut Dikonsumsi...
#    ✓ Doc 1058: Ikan Mahi-Mahi, Ini Kandungan Gizi dan Manfaatnya untuk Kese...
#    ✓ Doc 1061: Diet TKTP, Inilah Cara Melakukannya yang Aman dan Efektif...
#    ✓ Doc 1062: Tinggi Badan Anak yang Ideal dan Cara Memaksimalkan Pertumbu...
#    ✓ Doc 1063: 6 Manfaat Buah Rambutan untuk Kesehatan...
#    ✓ Doc 1069: 8 Manfaat Telur Ayam Kampung bagi Kesehatan...
#    ✓ Doc 1076: 11 Makanan yang Mengandung Vitamin B Tinggi...
#    ✓ Doc 1079: Makan Tempe Mentah, Apakah Aman atau Berbahaya bagi Kesehata...
#    ✓ Doc 1081: Beragam Makanan yang Mengandung Lemak Baik...
#    ✓ Doc 1082: 10 Makanan Sumber Tembaga untuk Tingkatkan Daya Tahan Tubuh...
#    ✓ Doc 1089: Makanan yang Sering Dianggap Mengganggu Kesehatan Ini, Terny...
#    ✓ Doc 1092: 7 Cara Minum Air Hangat yang Benar agar Manfaatnya Maksimal...
#    ✓ Doc 1097: Cuka Putih, Ketahui Manfaat dan Cara Penggunaannya...
#    ✓ Doc 1111: Ikan Asin, Inilah Manfaat, Bahaya, dan Cara Aman Mengonsumsi...
#    ✓ Doc 1113: 5 Minuman Lebaran untuk Jaga Energi Tetap Kuat...
#    ✓ Doc 1120: Cermat Memilih Susu untuk Anak...
#    ✓ Doc 1124: Cara Tepat Menjaga Kesehatan Sistem Pencernaan Anak...
#    ✓ Doc 1128: 10 Manfaat Singkong Rebus yang Jarang Dibicarakan...
#    ✓ Doc 1144: 6 Jenis Makanan untuk Ibu Hamil agar Melahirkan Bayi Cerdas...
#    ✓ Doc 1146: Katsuobushi: Kandungan Gizi, Manfaat Kesehatan, dan Tips Men...
#    ✓ Doc 1150: Sarapan Bergizi, Kunci Awal Hari yang Sehat dan Berenergi...
#    ✓ Doc 1151: Nutrisi Anak: Kunci Agar Tetap Sehat dan Aktif Liburan di Mu...
#    ✓ Doc 1158: 5 Cara Mengatasi Berat Badan Kurang pada Anak...
#    ✓ Doc 1159: 9 Manfaat Alpukat untuk Kesehatan...
#    ✓ Doc 1162: 6 Cara Mengonsumsi Cuka Apel yang Perlu Diperhatikan...
#    ✓ Doc 1163: 12 Manfaat Telur Puyuh yang Jarang Diketahui...
#    ✓ Doc 1165: Susu Kurma vs Susu Biasa, Mana yang Lebih Sehat?...
#    ✓ Doc 1167: Daging Olahan, Kenali Risikonya dan Tips Konsumsi yang Aman...
#    ✓ Doc 1171: 4 Manfaat Kacang Panjang bagi Kesehatan...
#    ✓ Doc 1174: Penuhi Kebutuhan Omega 3 dari Beragam Makanan...
#    ✓ Doc 1176: Seputar Profesi Dokter Spesialis Gizi dan Perannya dalam Dun...
#    ✓ Doc 1185: Kenali Jenis dan Berbagai Sumber Lemak Tambahan MPASI...
#    ✓ Doc 1188: Saus Tiram: Manfaat, Cara Memilih, dan Tips Aman Mengonsumsi...
#    ✓ Doc 1191: Manfaat Susu Organik untuk Tumbuh Kembang Anak...
#    ✓ Doc 1193: Ikan Toman, Ini Kandungan Gizi dan Manfaatnya untuk Kesehata...
#    ✓ Doc 1200: Bahaya Buah Pir, Apakah Ada? Ini Faktanya...
#    ✓ Doc 1203: 9 Makanan Sumber Vitamin B1 yang Bernutrisi dan Mudah Ditemu...
#    ✓ Doc 1205: 8 Manfaat Ikan Gabus bagi Kesehatan yang Jarang Diketahui...
#    ✓ Doc 1208: Segudang Manfaat Buah Jeruk untuk Kesehatan...
#    ✓ Doc 1211: Makan Malam Membuat Berat Badan Naik, Mitos atau Fakta?...
#    ✓ Doc 1216: Makanan Pendamping ASI Bisa Dimulai dengan Menu Berikut...
#    ✓ Doc 1217: Kenali Penyebab Anak Kurang Gizi dan Gejala Awal yang Timbul...
#    ✓ Doc 1219: Ikan Wader, Nutrisi dan Manfaatnya yang Beragam...
#    ✓ Doc 1223: Daftar Bunga yang Bisa Dimakan, Beserta Manfaat dan Tips Men...
#    ✓ Doc 1225: Kalori Kerupuk Udang dan Cara Konsumsi yang Sehat...
#    ✓ Doc 1243: Ikan Salem, Ini Kandungan Gizi dan Manfaatnya untuk Kesehata...
#    ✓ Doc 1257: Bahaya Kekurangan Kalsium dan Cara Mencegahnya...
#    ✓ Doc 1258: Kerang Putih, Inilah Kandungan Nutrisi dan Ragam Manfaatnya ...
#    ✓ Doc 1260: Mengenal Amino Acid dan Fungsinya untuk Tubuh...
#    ✓ Doc 1267: Triptofan, Asam Amino Esensial yang Penting untuk Tubuh...
#    ✓ Doc 1268: 5 Manfaat Udang Sesuai Kandungan Nutrisinya...
#    ✓ Doc 1270: Amankah Memberikan Kismis kepada Anak?...
#    ✓ Doc 1273: Jangan Panik, Ini Tips Atasi Anak Susah Makan setelah Sakit...
#    ✓ Doc 1275: 6 Manfaat Telur Omega bagi Kesehatan Tubuh...
#    ✓ Doc 1279: 10 Makanan yang Mengandung Protein Tinggi dan Jumlah Asupann...
#    ✓ Doc 1285: Cara Merebus Telur yang Benar Agar Matang Sempurna dan Mudah...
#    ✓ Doc 1290: 3 Manfaat Daun Singkong dan Cara Mengolahnya...
#    ✓ Doc 1293: Manfaat Kacang Tanah sebagai Teman Diet...
#    ✓ Doc 1294: Buah yang Mengandung Vitamin B12, Apakah Ada?...
#    ✓ Doc 1299: Ikan Selar, Kandungan Gizi, Manfaat, dan Tips Mengonsumsinya...
#    ✓ Doc 1306: Daftar Makanan Berserat Sehari-hari dan Manfaatnya bagi Kese...
#    ✓ Doc 1308: 7 Manfaat Susu Kedelai bagi Kesehatan...
#    ✓ Doc 1312: 8 Manfaat Air Kelapa Hijau bagi Kesehatan...
#    ✓ Doc 1313: Manfaat Protein dan Sumbernya...
#    ✓ Doc 1314: Antisipasi Bahaya Kekurangan Kalium dari Sekarang...
#    ✓ Doc 1319: 10 Sayur Penambah Darah yang Bantu Atasi Anemia...
#    ✓ Doc 1322: 8 Manfaat Buah Naga untuk Anak...
#    ✓ Doc 1328: Daging Ayam Kampung, Ketahui Manfaat dan Tips Mengolahnya...
#    ✓ Doc 1335: 8 Manfaat Daun Kari yang Baik untuk Kesehatan Tubuh...
#    ✓ Doc 1340: Minyak Jelantah, Kenali Bahaya dan Cara Mengurangi Dampak Bu...
#    ✓ Doc 1342: Ini Berbagai Manfaat Susu sebagai Pelengkap Nutrisi Anak...
#    ✓ Doc 1343: 3 Menu Makan Malam untuk Keluarga yang Sehat dan Lezat...
#    ✓ Doc 1350: 12 Suplemen Makanan yang Penuh Nutrisi...
#    ✓ Doc 1353: Ingin Otak Anak Cerdas? Yuk, Cukupi Asupan DHA dan Omega-3...
#    ✓ Doc 1354: Cara Mencegah Anak Gampang Sakit Saat Cuaca Tidak Menentu...
#    ✓ Doc 1356: 4 Manfaat Ngemil untuk Tubuh yang Perlu Diketahui...
#    ✓ Doc 1362: Daging Kerbau, Inilah Kandungan Nutrisi, Manfaat, dan Tips A...
#    ✓ Doc 1366: 9 Risiko Mengonsumsi Makanan Cepat Saji secara Berlebihan...
#    ✓ Doc 1369: Peran Ibu dalam Tumbuh Kembang Anak...
#    ✓ Doc 1370: Ikan Belida, Sumber Protein Air Tawar yang Lezat dan Kaya Ma...
#    ✓ Doc 1371: Segudang Manfaat Jus Mangga Bagi Kesehatan...
#    ✓ Doc 1373: Makanan Kaleng, Simak Kelebihan dan Kekurangannya...
#    ✓ Doc 1377: Ikan Kuwe, Inilah Nutrisi, Manfaat, dan Cara Mengolahnya...
#    ✓ Doc 1378: Memilih Susu Bubuk yang Tepat untuk Anak...
#    ✓ Doc 1381: Anjuran Ahli Gizi Terkait Pola Makan Sehat dan Tepat...
#    ✓ Doc 1383: 7 Manfaat STMJ bagi Kesehatan dan Tips Mengonsumsinya...
#    ✓ Doc 1392: 8 Manfaat Anggur Merah untuk Kesehatan...
#    ✓ Doc 1394: Pilihan Camilan Sehat untuk Anak 1 Tahun...
#    ✓ Doc 1400: Buah Kemang, Manfaat dan Hal-Hal yang Harus Diperhatikan seb...
#    ✓ Doc 1404: Raw Milk: Pahami Risiko dan Fakta Medis dari Konsumsi Susu M...
#    ✓ Doc 1405: Scoville, Satuan Ukur Pedas yang Wajib Diketahui Pecinta Cab...
#    ✓ Doc 1406: Ikan Bilis, Inilah Kandungan Nutrisi, Potensi Manfaat, dan T...
#    ✓ Doc 1407: Ikan Todak, Ini Kandungan Gizi dan Manfaatnya untuk Kesehata...
#    ✓ Doc 1412: Teh Madu, Inilah Kandungan Potensi Manfaat yang Sayang Dilew...
#    ✓ Doc 1413: 7 Manfaat Buah Pace dan Efek Sampingnya untuk Kesehatan...
#    ✓ Doc 1420: 7 Manfaat Kecambah dan Cara Aman Mengonsumsinya...
#    ✓ Doc 1422: Yodium, Kenali Manfaat dan Akibat Kekurangannya...
#    ✓ Doc 1430: Ikan Manyung, Ini Manfaat dan Cara Aman Mengonsumsinya...
#    ✓ Doc 1433: Inilah Manfaat Cangkang Telur yang Jarang Diketahui...
#    ✓ Doc 1434: Ikan Pari, Pertimbangkan Manfaat dan Risiko Kesehatan di Bal...
#    ✓ Doc 1439: 11 Manfaat Kacang Tanah bagi Kesehatan Tubuh...
#    ✓ Doc 1440: Manfaat Vitamin D Tidak Hanya Untuk Tulang...
#    ✓ Doc 1443: Kurma Basah, Inilah Kandungan Nutrisi dan Manfaatnya bagi Ke...
#    ✓ Doc 1447: 8 Manfaat Pisang bagi Kesehatan Tubuh...
#    ✓ Doc 1448: Pola Makan Sehat Penambah Stamina...
#    ✓ Doc 1449: 6 Bahaya Mie Instan Jika Dikonsumsi Terlalu Sering...
#    ✓ Doc 1459: 5 Manfaat Buah Sirsak untuk Kesehatan...
#    ✓ Doc 1463: Fungsi Fosfor bagi Tubuh Beserta Sumbernya...
#    ✓ Doc 1468: Makanan untuk Program Hamil yang Sukses...
#    ✓ Doc 1470: 6 Manfaat Buah Anggur untuk Kesehatan Anak...
#    ✓ Doc 1473: Surplus Kalori, Dampaknya bagi Tubuh dan Cara Melakukannya d...
#    ✓ Doc 1474: Perbedaan Daging Sapi dan Babi yang Perlu Diketahui...
#    ✓ Doc 1481: 8 Manfaat Telur untuk Anak...
#    ✓ Doc 1484: 7 Manfaat Buah Kiwi bagi Kesehatan...
#    ✓ Doc 1486: Daging Buaya, Ketahui Manfaat dan Risiko Mengonsumsinya...
#    ✓ Doc 1488: Ikan Shisamo, Kandungan Gizi, Manfaat, dan Tips Memilihnya a...
#    ✓ Doc 1492: Ketahui Kalori Ayam Goreng Tepung dan Tips Aman Mengonsumsin...
#    ✓ Doc 1499: Keju Edam, Inilah Kandungan Nutrisi dan Berbagai Potensi Man...
#    ✓ Doc 1501: Temu Mangga, Herbal Beraroma Khas yang Punya Banyak Manfaat...
#    ✓ Doc 1504: Minum Teh setelah Makan, Ini Dampaknya pada Tubuh...
#    ✓ Doc 1509: Kontroversi Kacang Kedelai Terkait Alergi dan Kesuburan...
#    ✓ Doc 1510: Anggur Laut, Ketahui Nutrisi dan Manfaatnya...
#    ✓ Doc 1511: 7 Susu Nabati yang Lezat dan Bernutrisi...
#    ✓ Doc 1516: Ikan Hiu, Ketahui Hal Ini Sebelum Mengonsumsinya...
#    ✓ Doc 1517: Tempe Kacang Hijau, Inilah Kandungan Nutrisi, Manfaat, dan C...
#    ✓ Doc 1527: Kandungan Gizi dan Manfaat Makanan Laut untuk Kesehatan...
#    ✓ Doc 1531: Tepung Tapioka, Bahan Serbaguna yang Bebas Gluten...
#    ✓ Doc 1534: Antosianin, Senyawa dalam Buah dan Sayur dengan Banyak Manfa...
#    ✓ Doc 1536: Gula Pasir, Inilah Manfaat dan Risiko di Baliknya...
#    ✓ Doc 1541: 7 Manfaat Terong Pipit untuk Kesehatan Tubuh...
#    ✓ Doc 1542: 6 Vitamin untuk Otak yang Baik Dikonsumsi...

# %%
class Evaluator:
    def __init__(self, retrieval_engine):
        self.engine = retrieval_engine
        
    def precision_at_k(self, retrieved_docs, relevant_docs, k):
        """Hitung Precision@K"""
        retrieved_k = retrieved_docs[:k]
        relevant_retrieved = len(set(retrieved_k) & set(relevant_docs))
        return relevant_retrieved / k if k > 0 else 0
    
    def recall_at_k(self, retrieved_docs, relevant_docs, k):
        """Hitung Recall@K"""
        retrieved_k = retrieved_docs[:k]
        relevant_retrieved = len(set(retrieved_k) & set(relevant_docs))
        return relevant_retrieved / len(relevant_docs) if len(relevant_docs) > 0 else 0
    
    def f1_score(self, precision, recall):
        """Hitung F1-Score"""
        if precision + recall == 0:
            return 0
        return 2 * (precision * recall) / (precision + recall)
    
    def average_precision(self, retrieved_docs, relevant_docs):
        """Hitung Average Precision"""
        if len(relevant_docs) == 0:
            return 0
        
        precision_sum = 0
        relevant_count = 0
        
        for k, doc_id in enumerate(retrieved_docs, 1):
            if doc_id in relevant_docs:
                relevant_count += 1
                precision_sum += relevant_count / k
        
        return precision_sum / len(relevant_docs)
    
    def evaluate(self, eval_queries, k_values=[1, 3, 5]):
        """Evaluasi sistem dengan multiple queries"""
        results = {
            'queries': [],
            'precision': {f'P@{k}': [] for k in k_values},  
            'recall': {f'R@{k}': [] for k in k_values},    
            'f1': {f'F1@{k}': [] for k in k_values},       
            'ap': []                                       
        }
        
        for eval_query in eval_queries:
            query = eval_query['query']
            relevant_docs = eval_query['relevant_docs']
            
            # Retrieve dokumen
            search_result = self.engine.search(query, top_k=max(k_values))
            retrieved_docs = [int(r['doc_id']) for r in search_result['results']]
            
            # Hitung metrik untuk setiap k
            query_metrics = {'query': query}
            
            for k in k_values:
                p_at_k = self.precision_at_k(retrieved_docs, relevant_docs, k)
                r_at_k = self.recall_at_k(retrieved_docs, relevant_docs, k)
                f1 = self.f1_score(p_at_k, r_at_k)
                
                results['precision'][f'P@{k}'].append(p_at_k)
                results['recall'][f'R@{k}'].append(r_at_k)
                results['f1'][f'F1@{k}'].append(f1)
                
                query_metrics[f'P@{k}'] = p_at_k
                query_metrics[f'R@{k}'] = r_at_k
                query_metrics[f'F1@{k}'] = f1
            
            # Average Precision
            ap = self.average_precision(retrieved_docs, relevant_docs)
            results['ap'].append(ap)
            query_metrics['AP'] = ap
            
            results['queries'].append(query_metrics)
        
        # Hitung rata-rata (lebih simple: 'mean' bukan 'mean_metrics')
        results['mean'] = {
            **{k: np.mean(v) for k, v in results['precision'].items()},
            **{k: np.mean(v) for k, v in results['recall'].items()},
            **{k: np.mean(v) for k, v in results['f1'].items()},
            'MAP': np.mean(results['ap'])
        }
        
        return results

# Inisialisasi
evaluator = Evaluator(retrieval_engine)
eval_results = evaluator.evaluate(EVALUATION_QUERIES, k_values=[1, 3, 5])

# %%
# INI SUDAH BENAR! ✅
eval_results = evaluator.evaluate(EVALUATION_QUERIES, k_values=[1, 3, 5])

print("\nMetrik Rata-rata:")
for metric, value in eval_results['mean'].items():
    print(f"{metric:10s}: {value:.4f}")

print("\nDetail per Query:")
for i, q_res in enumerate(eval_results['queries'][:5]):
    print(f"\nQuery: {q_res['query']}")
    print(f"  P@5 : {q_res['P@5']:.4f}")
    print(f"  AP  : {q_res['AP']:.4f}")
# Out:
# Metrik Rata-rata:
# P@1       : 0.6667
# P@3       : 0.6667
# P@5       : 0.6000
# R@1       : 0.0022
# R@3       : 0.0612
# R@5       : 0.0643
# F1@1      : 0.0044
# F1@3      : 0.0667
# F1@5      : 0.0589
# MAP       : 0.0265
#
# Detail per Query:
#
# Query: cara menurunkan berat badan dengan jus
#   P@5 : 0.8000
#   AP  : 0.0058
#
# Query: obesitas pada anak dan cara mengatasinya
#   P@5 : 1.0000
#   AP  : 0.0157
#
# Query: teknik memasak yang mempertahankan nutrisi
#   P@5 : 0.6000
#   AP  : 0.0133
#
# Query: resep makanan tanpa gluten
#   P@5 : 0.0000
#   AP  : 0.0000
#
# Query: diet detoks dengan cold pressed juice
#   P@5 : 0.2000
#   AP  : 0.1111
